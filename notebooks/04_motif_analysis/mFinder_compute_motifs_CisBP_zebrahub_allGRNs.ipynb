# %% [markdown]
# # A template notebook to run mFinder from Uri Alon's lab
#
# - mFinder is a package to compute network motifs, a pattern of motifs that is over-represented than randomly permuted network.
#
# - Designed for Windows machine, but can run on Linux environment.
# - mfinder 1.21 is used here.
#
# Last updated: 09/19/2023
#
# Author: Yang-Joon Kim

# %%
# 0. Import
import os
import sys

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scanpy as sc
import seaborn as sns

# %%
import celloracle as co
co.__version__
# Out:
# /home/yang-joon.kim/.conda/envs/celloracle_env/lib/python3.8/site-packages/loompy/bus_file.py:68: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def twobit_to_dna(twobit: int, size: int) -> str:
# /home/yang-joon.kim/.conda/envs/celloracle_env/lib/python3.8/site-packages/loompy/bus_file.py:85: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def dna_to_twobit(dna: str) -> int:
# /home/yang-joon.kim/.conda/envs/celloracle_env/lib/python3.8/site-packages/loompy/bus_file.py:102: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def twobit_1hamming(twobit: int, size: int) -> List[int]:
# INFO:matplotlib.font_manager:Failed to extract font properties from /usr/share/fonts/google-noto-emoji/NotoColorEmoji.ttf: In FT2Font: Can not load face (unknown file format; error code 0x2)
# '0.14.0'

# %%
# visualization settings
# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

plt.rcParams['figure.figsize'] = [6, 4.5]
plt.rcParams["savefig.dpi"] = 300

# %% [markdown]
# # Main Command - using for loop to run mFinder for all cell-types and all timepoints(stages)

# %%
# Change the current working directory
#os.chdir("/hpc/projects/data.science/yangjoon.kim/github_repos/mfinder/mfinder1.21/")
#! export PATH=/hpc/projects/data.science/yangjoon.kim/github_repos/mfinder/mfinder1.21:$PATH
#os.system("export PATH=/hpc/projects/data.science/yangjoon.kim/github_repos/mfinder/mfinder1.21:$PATH")

# %%
# set the mfinder path in the PATH variable
mfinder_path = "/hpc/projects/data.science/yangjoon.kim/github_repos/mfinder/mfinder1.21"

cmd = "export PATH="+mfinder_path+":$PATH"
cmd

os.system(cmd)
# Out:
# 0

# %% [markdown]
# ## Step 1. Define the master adata object with all timepoints
#
# -

# %%
# move to the directory where the output files will be saved (motif txt)
filepath = "/hpc/projects/data.science/yangjoon.kim/zebrahub_multiome/data/processed_data/baseGRN_CisBP_RNA_zebrahub/09_network_motifs/"
os.chdir(filepath)

# %%
# Load the zebrahub early timepoints
zebrahub = sc.read_h5ad("/hpc/projects/data.science/yangjoon.kim/zebrahub_multiome/data/annotated_data/ZF_atlas_v01/ZF_atlas_v01.h5ad")
zebrahub
# Out:
# AnnData object with n_obs × n_vars = 38189 × 27877
#     obs: 'n_genes', 'n_counts', '10X_run', 'fish', 'fish_n', 'timepoint', 'seqrun', 'log_ncounts', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_nc', 'pct_counts_nc', 'cell_annotation', 'global_annotation'
#     var: 'gene_ids', 'feature_types', 'genome', 'mt', 'nc', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'n_cells', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'fish_colors', 'global_annotation_colors', 'hvg', 'neighbors', 'pca', 'timepoint_colors', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     layers: 'counts'
#     obsp: 'connectivities', 'distances'

# %%
zebrahub.obs.timepoint.unique()
# Out:
# ['10somite', '0 budstage', '20somite', '30somite', '5somite', '15somite']
# Categories (6, object): ['0 budstage', '5somite', '10somite', '15somite', '20somite', '30somite']

# %%
timepoints = ['0 budstage','5somite','10somite','15somite','20somite','30somite']
timepoints
# Out:
# ['0 budstage', '5somite', '10somite', '15somite', '20somite', '30somite']

# %%
stage = timepoints[0]

GRN_stage = co.load_hdf5(links_filepath + "08_"+stage+"_celltype_GRNs.celloracle.links")
GRN_stage.filtered_links
# Out:
# {'Differentiating_Neurons':          source   target  coef_mean  coef_abs             p      -logp
#  86657     nhlh2      dla   0.143526  0.143526  1.248927e-17  16.903463
#  34191     foxd2     btg1   0.129191  0.129191  4.572162e-10   9.339878
#  86689    zbtb18      dla   0.127046  0.127046  1.403359e-13  12.852831
#  110654  uncx4.1    fgf8a   0.111938  0.111938  4.035099e-13  12.394146
#  80220   uncx4.1  cyp26c1   0.106434  0.106434  1.181142e-17  16.927698
#  ...         ...      ...        ...       ...           ...        ...
#  232407    meis3    olig4   0.023177  0.023177  1.894128e-08   7.722591
#  169224   hoxc1a     irx7  -0.023163  0.023163  4.268921e-08   7.369682
#  342603    mafbb     tmsb   0.023161  0.023161  7.182542e-09   8.143722
#  16973     tlx3b    apoc1   0.023159  0.023159  4.092135e-04   3.388050
#  154290     arxb   hoxb1b  -0.023143  0.023143  7.714583e-09   8.112688
#
#  [2000 rows x 6 columns],
#  'Endoderm':         source   target  coef_mean  coef_abs             p      -logp
#  34183    gata5     btg1   0.179640  0.179640  1.108055e-13  12.955439
#  358464  foxf2a      ved  -0.123337  0.123337  3.921108e-09   8.406591
#  34213   tcf7l2     btg1   0.111344  0.111344  6.813417e-08   7.166635
#  34203    foxl1     btg1   0.107486  0.107486  7.240471e-09   8.140233
#  358444  sox11b      ved   0.093079  0.093079  2.787509e-07   6.554784
#  ...        ...      ...        ...       ...           ...        ...
#  176058   gata6  kctd15a  -0.015641  0.015641  6.588633e-11  10.181205
#  180395   jdp2b     krt8   0.015637  0.015637  3.104431e-08   7.508018
#  379011  foxi3b   znfl2a   0.015636  0.015636  1.096266e-04   3.960084
#  330690  sox11b     tbx1  -0.015626  0.015626  3.339792e-06   5.476281
#  7889      shox  akap12b   0.015623  0.015623  2.491926e-06   5.603465
#
#  [2000 rows x 6 columns],
#  'Epidermal':          source   target  coef_mean  coef_abs             p      -logp
#  358444   sox11b      ved  -0.283970  0.283970  5.066188e-10   9.295319
#  34219     gata3     btg1   0.266665  0.266665  6.168458e-13  12.209823
#  358421   sox11a      ved  -0.263952  0.263952  1.593111e-06   5.797754
#  245075     hey1     pfn1   0.242987  0.242987  1.083408e-16  15.965208
#  34199    gata2a     btg1   0.222484  0.222484  1.143262e-09   8.941854
#  ...         ...      ...        ...       ...           ...        ...
#  289119  phox2bb  shisa2a   0.041243  0.041243  4.173013e-11  10.379550
#  57957    foxj1b    cldna  -0.041237  0.041237  1.057354e-14  13.975779
#  57931      uncx    cldna  -0.041220  0.041220  8.402299e-09   8.075602
#  104658     sox3     eya1   0.041219  0.041219  3.087405e-12  11.510406
#  316027    msx1b    sox13   0.041218  0.041218  2.356431e-13  12.627745
#
#  [2000 rows x 6 columns],
#  'Germline':          source      target  coef_mean  coef_abs             p      -logp
#  358436    sox10         ved  -0.088445  0.088445  2.148496e-11  10.667865
#  358439    sox4b         ved   0.084442  0.084442  1.429669e-05   4.844765
#  358441     sox3         ved  -0.063088  0.063088  6.276520e-07   6.202281
#  154211    mixl1      hoxb1b  -0.062281  0.062281  8.077366e-10   9.092730
#  358462    mafbb         ved   0.059307  0.059307  3.844072e-04   3.415208
#  ...         ...         ...        ...       ...           ...        ...
#  17118     rarga       apoc1   0.008696  0.008696  3.102859e-07   6.508238
#  365066    pitx1  zgc:110425   0.008688  0.008688  8.288355e-06   5.081532
#  120785    pax3a      fthl27   0.008680  0.008680  1.751482e-07   6.756594
#  195757  hoxb13a        mdkb   0.008677  0.008677  6.677630e-05   4.175378
#  161459     sp5a         id3   0.008676  0.008676  5.856458e-05   4.232365
#
#  [2000 rows x 6 columns],
#  'Lateral_Mesoderm':         source   target  coef_mean  coef_abs             p      -logp
#  358419  foxc1a      ved  -0.281434  0.281434  1.634938e-11  10.786499
#  358430   foxd2      ved  -0.235953  0.235953  2.134200e-11  10.670765
#  358439   sox4b      ved   0.208662  0.208662  9.009097e-09   8.045319
#  358468    gcm2      ved   0.202189  0.202189  2.252831e-12  11.647271
#  358443   pax2a      ved  -0.199601  0.199601  1.271333e-11  10.895741
#  ...        ...      ...        ...       ...           ...        ...
#  87099     drgx      dlc  -0.033177  0.033177  1.086396e-12  11.964012
#  50118   hoxb7a    cdx1a   0.033176  0.033176  5.435604e-17  16.264752
#  94465    tbx16  efemp2b   0.033166  0.033166  2.945419e-12  11.530853
#  314200   foxe3   socs3a   0.033165  0.033165  3.793304e-08   7.420982
#  271865  mef2ca     rhov   0.033164  0.033164  2.468161e-10   9.607626
#
#  [2000 rows x 6 columns],
#  'Muscle':         source      target  coef_mean  coef_abs             p      -logp
#  196972   egr2a      mespab   0.159530  0.159530  3.237219e-16  15.489828
#  10429   zbtb18      alpi.1   0.142937  0.142937  1.018552e-14  13.992017
#  332324   mef2d        tbx6   0.138961  0.138961  7.120085e-14  13.147515
#  2817    zbtb18      actc1a   0.138058  0.138058  1.403663e-11  10.852737
#  208331  zbtb18       myl10   0.136692  0.136692  5.193597e-14  13.284532
#  ...        ...         ...        ...       ...           ...        ...
#  272838   foxd2     ripply2   0.029088  0.029088  7.653369e-05   4.116147
#  365000  dmrt2a  zgc:110425   0.029086  0.029086  2.052247e-08   7.687770
#  114088    sox6        fn1b   0.029081  0.029081  2.530927e-07   6.596720
#  375078  hoxc3a   zgc:56585   0.029074  0.029074  1.695497e-12  11.770703
#  22747    hmx3a        asph  -0.029073  0.029073  1.949037e-04   3.710180
#
#  [2000 rows x 6 columns],
#  'NMPs':          source   target  coef_mean  coef_abs             p      -logp
#  358439    sox4b      ved   0.261958  0.261958  1.277100e-14  13.893775
#  358422   sox19a      ved  -0.139080  0.139080  4.481563e-13  12.348570
#  358461   tcf7l2      ved   0.125323  0.125323  1.341573e-08   7.872386
#  331068    sox4b    tbx16   0.120076  0.120076  1.248914e-15  14.903468
#  28455      eve1   bambia   0.118482  0.118482  2.315701e-15  14.635317
#  ...         ...      ...        ...       ...           ...        ...
#  113886     sox2     fn1a  -0.026103  0.026103  1.985295e-10   9.702175
#  82149    foxj1a     dag1  -0.026098  0.026098  1.041979e-06   5.982141
#  4693       eve1  adipor2   0.026081  0.026081  7.924082e-17  16.101051
#  195712  hoxc13a     mdkb   0.026078  0.026078  8.142323e-10   9.089252
#  153441   hoxa4a   hoxa9a   0.026077  0.026077  7.392506e-10   9.131208
#
#  [2000 rows x 6 columns],
#  'Neural_Anterior':        source      target  coef_mean  coef_abs             p      -logp
#  238198   en2a       pax2a   0.268953  0.268953  1.788528e-14  13.747504
#  77840     rx3      cxcr4a   0.245100  0.245100  8.288253e-16  15.081537
#  148032   en2a        her5   0.241369  0.241369  7.076461e-18  17.150184
#  99261   pax2a        en2a   0.228258  0.228258  3.129809e-18  17.504482
#  368394  foxp4  zgc:153409   0.220184  0.220184  7.511124e-15  14.124295
#  ...       ...         ...        ...       ...           ...        ...
#  38795   pax3a      calr3b   0.044897  0.044897  1.513212e-13  12.820100
#  351025   emx2      tuba1a   0.044894  0.044894  1.156708e-07   6.936776
#  316978   lhx5        sox2   0.044876  0.044876  2.725028e-08   7.564629
#  23078     jun        atf3   0.044873  0.044873  1.615609e-13  12.791664
#  372071   en1b  zgc:173587  -0.044860  0.044860  8.466925e-09   8.072274
#
#  [2000 rows x 6 columns],
#  'Neural_Crest':          source  target  coef_mean  coef_abs             p      -logp
#  34204      zic6    btg1   0.068596  0.068596  5.324246e-11  10.273742
#  238415   nr2f1b   pax3a   0.067659  0.067659  1.214941e-16  15.915445
#  154440    shox2  hoxb3a   0.064674  0.064674  6.621051e-08   7.179073
#  377656   nr2f1b   zic2a   0.062994  0.062994  3.387868e-09   8.470074
#  196417    meis3  meis2a   0.061817  0.061817  8.455832e-11  10.072844
#  ...         ...     ...        ...       ...           ...        ...
#  227304   tfap2a  nrarpa   0.014046  0.014046  1.054752e-08   7.976850
#  359367  onecut1     vox  -0.014045  0.014045  1.775671e-06   5.750637
#  240599     sp5l  pcdh19   0.014040  0.014040  2.417189e-09   8.616689
#  161193    shox2    id2a   0.014038  0.014038  1.756139e-04   3.755441
#  161192    msx1b    id2a   0.014032  0.014032  1.021096e-08   7.990933
#
#  [2000 rows x 6 columns],
#  'Neural_Posterior':         source  target  coef_mean  coef_abs             p      -logp
#  238438   msx1b   pax3a   0.266057  0.266057  2.233909e-17  16.650935
#  17086    msx1b   apoc1   0.259281  0.259281  1.242339e-18  17.905760
#  86677   sox11a     dla   0.228103  0.228103  1.201533e-19  18.920264
#  154172  hnf1ba  hoxb1b   0.200058  0.200058  1.212904e-17  16.916174
#  152016   meis3  hnf1ba   0.199326  0.199326  2.207879e-17  16.656025
#  ...        ...     ...        ...       ...           ...        ...
#  378956  hoxc6b  znfl2a   0.041696  0.041696  1.250876e-13  12.902786
#  195758   klf17    mdkb  -0.041693  0.041693  5.598605e-11  10.251920
#  110329  tfap2a    fgf3  -0.041686  0.041686  3.707827e-12  11.430881
#  148220    foxa    her6   0.041684  0.041684  9.189336e-11  10.036716
#  147824    emx2  her4.4   0.041680  0.041680  1.503864e-09   8.822791
#
#  [2000 rows x 6 columns],
#  'Notochord':          source      target  coef_mean  coef_abs             p      -logp
#  34213    tcf7l2        btg1   0.138960  0.138960  1.056249e-11  10.976234
#  34189    foxi3a        btg1   0.113222  0.113222  1.365006e-08   7.864865
#  148911    foxd3        hes6   0.107777  0.107777  8.125356e-12  11.090158
#  113863     mnx1        fn1a   0.106886  0.106886  4.574540e-16  15.339653
#  34202    dmrt3a        btg1   0.102094  0.102094  9.980856e-13  12.000832
#  ...         ...         ...        ...       ...           ...        ...
#  161995   sox11a       ier2a   0.020842  0.020842  5.369809e-13  12.270041
#  368391  phox2bb  zgc:153409  -0.020833  0.020833  2.155462e-06   5.666460
#  172912    dlx2a       jdp2b   0.020832  0.020832  1.158611e-04   3.936062
#  147875    nhlh2      her4.4   0.020829  0.020829  1.747587e-09   8.757561
#  223030   foxj1b       nova2   0.020826  0.020826  2.449883e-07   6.610855
#
#  [2000 rows x 6 columns],
#  'PSM':          source      target  coef_mean  coef_abs             p      -logp
#  358419   foxc1a         ved  -0.369738  0.369738  6.517406e-16  15.185925
#  358416     pax5         ved   0.251017  0.251017  1.719259e-13  12.764659
#  358438     egr4         ved   0.199000  0.199000  2.848313e-10   9.545412
#  358439    sox4b         ved   0.174633  0.174633  1.380857e-07   6.859851
#  10429    zbtb18      alpi.1   0.156871  0.156871  1.298534e-17  16.886547
#  ...         ...         ...        ...       ...           ...        ...
#  20530   hoxb10a      arl4aa  -0.031318  0.031318  1.130528e-11  10.946719
#  227314   foxo1a      nrarpa  -0.031313  0.031313  2.458843e-09   8.609269
#  346903   hoxc1a       tob1a  -0.031309  0.031309  1.372716e-16  15.862419
#  165446    pbx1a  im:7138239   0.031307  0.031307  1.128094e-06   5.947655
#  348245   hoxb5b        tpm3   0.031305  0.031305  6.969616e-13  12.156791
#
#  [2000 rows x 6 columns],
#  'Somites':         source   target  coef_mean  coef_abs             p      -logp
#  358430   foxd2      ved  -0.201453  0.201453  8.021183e-16  15.095762
#  197037  dmrt2a   mespab   0.198571  0.198571  1.016912e-16  15.992717
#  196815  hoxc6b   mespaa   0.196897  0.196897  7.465155e-17  16.126961
#  332389  dmrt2a     tbx6   0.190522  0.190522  5.323086e-15  14.273836
#  196758  hoxb3a    meox1   0.186918  0.186918  1.006142e-12  11.997341
#  ...        ...      ...        ...       ...           ...        ...
#  87037    barx1      dlc   0.037743  0.037743  5.479247e-11  10.261279
#  285163   alx4a  sema3aa   0.037727  0.037727  8.268290e-13  12.082584
#  22938    tbx16     aspm   0.037720  0.037720  1.547360e-16  15.810409
#  154452  nr2f1a   hoxb3a   0.037703  0.037703  2.981958e-06   5.525498
#  156270   six1b   hoxc6b  -0.037702  0.037702  1.789292e-13  12.747319
#
#  [2000 rows x 6 columns],
#  'unassigned':         source      target  coef_mean  coef_abs             p      -logp
#  358439   sox4b         ved   0.312611  0.312611  6.390484e-14  13.194466
#  180509   gata3       krt91   0.272480  0.272480  1.103619e-12  11.957181
#  180483  gata2a       krt91   0.262806  0.262806  1.988116e-11  10.701558
#  358455   sox9b         ved  -0.227327  0.227327  1.463048e-13  12.834741
#  180474  foxi3a       krt91   0.219864  0.219864  8.605696e-13  12.065214
#  ...        ...         ...        ...       ...           ...        ...
#  88145    dlx2a       dlx3b   0.053395  0.053395  6.867209e-12  11.163220
#  203097  hoxb8a       msgn1   0.053377  0.053377  1.636242e-09   8.786153
#  22891    mef2d        aspm   0.053363  0.053363  3.623438e-13  12.440879
#  374691    eve1  zgc:194989   0.053357  0.053357  4.533264e-09   8.343589
#  125811   foxi1      gata2a   0.053347  0.053347  1.572447e-10   9.803424
#
#  [2000 rows x 6 columns]}

# %%
filepath
# Out:
# '/hpc/projects/data.science/yangjoon.kim/zebrahub_multiome/data/processed_data/baseGRN_CisBP_RNA_zebrahub/09_network_motifs/'

# %%
# Run mFinder for all timepoints and all cell-types

links_filepath = "/hpc/projects/data.science/yangjoon.kim/zebrahub_multiome/data/processed_data/baseGRN_CisBP_RNA_zebrahub/"

for stage in timepoints:
    # import the Links object
    GRN_stage = co.load_hdf5(links_filepath + "08_"+stage+"_celltype_GRNs.celloracle.links")
    # grab only the filtered GRNs (2000 edges for each GRN)
    GRN_all = GRN_stage.filtered_links
    
    # for each cell-type, run mFinder
    for celltype in GRN_all.keys():

        print(celltype)

        # Step 1. subset the GRN for each celltype
        GRN_celltype = GRN_all[celltype]

        # Step 2. reformat the GRN (unique integers for gene_names)    
        list_genes_TFs = list(set(GRN_celltype.source).union(set(GRN_celltype.target)))
        # Create a dictionary mapping integers to gene names
        gene_dict = {index: gene_name for index, gene_name in enumerate(list_genes_TFs)}
        gene_dict

        # Now, we will reformat the GRN as described above
        # 1) grab the GRN, then extract the "source", "target", and create a dataframe
        # 2) add the "edge weight" as "1" for the third column
        df_mfinder = pd.DataFrame(columns =["source", "target", "edge_weight"])
        df_mfinder

        df_mfinder["source"] = GRN_celltype["source"]
        df_mfinder["target"] = GRN_celltype["target"]
        df_mfinder["edge_weight"] = 1

        df_mfinder

        # 3) convert the "source", "target" gene_names to "integers" using the gene_dict
        df_mfinder["source"] = df_mfinder["source"].map({v: k for k, v in gene_dict.items()})
        df_mfinder["target"] = df_mfinder["target"].map({v: k for k, v in gene_dict.items()})
        df_mfinder
        # save the reformatted GRN into a txt file
        df_mfinder.to_csv(filepath + "filtered_GRN_"+stage+"_"+celltype+"_mfinder_format.txt",
                          sep="\t", header=False, index=False)

        # Step 3. run mFinder
        # default setting (network_size=3, num_random_)
        # input filename
        input_file = "filtered_GRN_"+stage+"_"+celltype+"_mfinder_format.txt"
        # output filename
        output_file = "motifs_"+stage+"_"+celltype

        # define the mFinder command
        cmd = "mfinder "+input_file + " -f "+output_file
        cmd
        # run mFinder
        os.system(cmd)
        print(stage + "_" + celltype + " network motif computing completed")
# Out:
# Differentiating_Neurons
# Usage : mfinder <Network input file name> -s <motif size> -r <no. of randon networks> [-f <output file name>] [more flags]
#
# 	-s <motif size>  :Motif size to search
# 	-r <rand net num> :Number of random networks to generate
# 	-f <output file name>  : Output file name
# 	-nd : Input network is a non-directed network.
# 	-p <num of samples>: run with Sampling method,
# 	-omem : output members list of all subgraphs
# 	-h : help
#
# 	Additional flags:
#
# 	Motif criteria flags:
# 	-m <value> : mfactor threshold to use when calculating motifs
# 	-z <value> : Z-score threshold to use when calculating motifs
# 	-u : Uniqueness threshold
# 	-nu : Dont count uniqueness and ignore uniqueness threshold
#
# 	Random networks randomization flags:
#
# 	-rs : use stubs method for generating random networks
# 	-rclust : Preserve clustering sequence in random networks
# 	-met :Use Metropolis algorithm to conserve triad-census
# 		in random networks
# 		(for s>3; Default : Do not use Metropolis)
# 	-t0 <(default 0.001)> :Initial temperature (-m0 budstage_Differentiating_Neurons network motif computing completed
# Endoderm
# et option)
# 	-iter <(default 2)> :controls how many steps to perform (-met option)
# 	-eth  <(default 0.005)> : energy threshhold (-met option)
# 	-rgrass <colony size>: generate random networks using grassberger
# 		algorithm
# 	-rgrass_max_sz <max ratio>: Limit maximal colony size ratio
# 	-rdm: don't conserve mutual edges in random networks
# 	-rcl <layers num><size1 size2 ..sizem>: conserve layers in random
# 		 networks
# 	-nsr : Global Switches number when generating Random networks.
#
#
# 	Output files flags:
#
# 	-oi : output intermediate output file. Defualt :No:
# 	-ospmem <subgraph id>: output members list of a specific subgraphs only
# 	-maxmem <list length>: limit length of members list to 'list length'.
# 		Defualt: 1000
# 	-omat : output matrix format file ('__MAT.txt')
# 	-omet : output metropolis log
# 	-olog : output general log file
# 	-orall : output matrix format of appearances in each random network
# 	-ornet : output random networks files
# 	-otop <no. of top motifs> : No. of top motifs to show
# 	-onodangl: output a list of all nan-dangling detected motifs
#
# 	Other flags
#
# 	-ts : <target,source,weight> Old format of input network file
# 	-q :Quiet mode - No output to the screen
# 	-dd : Don't die mode. Wait to user action before terminating the
# 		program
# 	-pold <num of samples>: run sampling method old version
# 	-nor : Dont search Real network. Defualt :No:
# 	-cr : calculate roles statistics
# Usage : mfinder <Network input file name> -s <motif size> -r <no. of randon networks> [-f <output file name>] [more flags]
#
# 	-s <motif size>  :Motif size to search
# 	-r <rand net num> :Number of random networks to generate
# 	-f <output file name>  : Output file name
# 	-nd : Input network is a non-directed network.
# 	-p <num of samples>: run with Sampling method,
# 	-omem : output members list of all subgraphs
# 	-h : help
#
# 	Additional flags:
#
# 	Motif criteria flags:
# 	-m <value> : mfactor threshold to use when calculating motifs
# 	-z <value> : Z-score threshold to use when calculating motifs
# 	-u : Uniqueness threshold
# 	-nu : Dont count uniqueness and ignore uniqueness threshold
#
# 	Random networks randomization flags:
#
# 	-rs : use stubs method for generating random networks
# 	-rclust : Preserve clustering sequence in random networks
# 	-met :Use Metropolis algorithm to conserve triad-census
# 		in random networks
# 		(for s>3; Default : Do not use Metropolis)
# 	-t0 <(default 0.001)> :Initial temperature (-m0 budstage_Endoderm network motif computing completed
# Epidermal
# et option)
# 	-iter <(default 2)> :controls how many steps to perform (-met option)
# 	-eth  <(default 0.005)> : energy threshhold (-met option)
# 	-rgrass <colony size>: generate random networks using grassberger
# 		algorithm
# 	-rgrass_max_sz <max ratio>: Limit maximal colony size ratio
# 	-rdm: don't conserve mutual edges in random networks
# 	-rcl <layers num><size1 size2 ..sizem>: conserve layers in random
# 		 networks
# 	-nsr : Global Switches number when generating Random networks.
#
#
# 	Output files flags:
#
# 	-oi : output intermediate output file. Defualt :No:
# 	-ospmem <subgraph id>: output members list of a specific subgraphs only
# 	-maxmem <list length>: limit length of members list to 'list length'.
# 		Defualt: 1000
# 	-omat : output matrix format file ('__MAT.txt')
# 	-omet : output metropolis log
# 	-olog : output general log file
# 	-orall : output matrix format of appearances in each random network
# 	-ornet : output random networks files
# 	-otop <no. of top motifs> : No. of top motifs to show
# 	-onodangl: output a list of all nan-dangling detected motifs
#
# 	Other flags
#
# 	-ts : <target,source,weight> Old format of input network file
# 	-q :Quiet mode - No output to the screen
# 	-dd : Don't die mode. Wait to user action before terminating the
# 		program
# 	-pold <num of samples>: run sampling method old version
# 	-nor : Dont search Real network. Defualt :No:
# 	-cr : calculate roles statistics
# Usage : mfinder <Network input file name> -s <motif size> -r <no. of randon networks> [-f <output file name>] [more flags]
#
# 	-s <motif size>  :Motif size to search
# 	-r <rand net num> :Number of random networks to generate
# 	-f <output file name>  : Output file name
# 	-nd : Input network is a non-directed network.
# 	-p <num of samples>: run with Sampling method,
# 	-omem : output members list of all subgraphs
# 	-h : help
#
# 	Additional flags:
#
# 	Motif criteria flags:
# 	-m <value> : mfactor threshold to use when calculating motifs
# 	-z <value> : Z-score threshold to use when calculating motifs
# 	-u : Uniqueness threshold
# 	-nu : Dont count uniqueness and ignore uniqueness threshold
#
# 	Random networks randomization flags:
#
# 	-rs : use stubs method for generating random networks
# 	-rclust : Preserve clustering sequence in random networks
# 	-met :Use Metropolis algorithm to conserve triad-census
# 		in random networks
# 		(for s>3; Default : Do not use Metropolis)
# 	-t0 <(default 0.001)> :Initial temperature (-m0 budstage_Epidermal network motif computing completed
# Germline
# et option)
# 	-iter <(default 2)> :controls how many steps to perform (-met option)
# 	-eth  <(default 0.005)> : energy threshhold (-met option)
# 	-rgrass <colony size>: generate random networks using grassberger
# 		algorithm
# 	-rgrass_max_sz <max ratio>: Limit maximal colony size ratio
# 	-rdm: don't conserve mutual edges in random networks
# 	-rcl <layers num><size1 size2 ..sizem>: conserve layers in random
# 		 networks
# 	-nsr : Global Switches number when generating Random networks.
#
#
# 	Output files flags:
#
# 	-oi : output intermediate output file. Defualt :No:
# 	-ospmem <subgraph id>: output members list of a specific subgraphs only
# 	-maxmem <list length>: limit length of members list to 'list length'.
# 		Defualt: 1000
# 	-omat : output matrix format file ('__MAT.txt')
# 	-omet : output metropolis log
# 	-olog : output general log file
# 	-orall : output matrix format of appearances in each random network
# 	-ornet : output random networks files
# 	-otop <no. of top motifs> : No. of top motifs to show
# 	-onodangl: output a list of all nan-dangling detected motifs
#
# 	Other flags
#
# 	-ts : <target,source,weight> Old format of input network file
# 	-q :Quiet mode - No output to the screen
# 	-dd : Don't die mode. Wait to user action before terminating the
# 		program
# 	-pold <num of samples>: run sampling method old version
# 	-nor : Dont search Real network. Defualt :No:
# 	-cr : calculate roles statistics
# Usage : mfinder <Network input file name> -s <motif size> -r <no. of randon networks> [-f <output file name>] [more flags]
#
# 	-s <motif size>  :Motif size to search
# 	-r <rand net num> :Number of random networks to generate
# 	-f <output file name>  : Output file name
# 	-nd : Input network is a non-directed network.
# 	-p <num of samples>: run with Sampling method,
# 	-omem : output members list of all subgraphs
# 	-h : help
#
# 	Additional flags:
#
# 	Motif criteria flags:
# 	-m <value> : mfactor threshold to use when calculating motifs
# 	-z <value> : Z-score threshold to use when calculating motifs
# 	-u : Uniqueness threshold
# 	-nu : Dont count uniqueness and ignore uniqueness threshold
#
# 	Random networks randomization flags:
#
# 	-rs : use stubs method for generating random networks
# 	-rclust : Preserve clustering sequence in random networks
# 	-met :Use Metropolis algorithm to conserve triad-census
# 		in random networks
# 		(for s>3; Default : Do not use Metropolis)
# 	-t0 <(default 0.001)> :Initial temperature (-m0 budstage_Germline network motif computing completed
# Lateral_Mesoderm
# et option)
# 	-iter <(default 2)> :controls how many steps to perform (-met option)
# 	-eth  <(default 0.005)> : energy threshhold (-met option)
# 	-rgrass <colony size>: generate random networks using grassberger
# 		algorithm
# 	-rgrass_max_sz <max ratio>: Limit maximal colony size ratio
# 	-rdm: don't conserve mutual edges in random networks
# 	-rcl <layers num><size1 size2 ..sizem>: conserve layers in random
# 		 networks
# 	-nsr : Global Switches number when generating Random networks.
#
#
# 	Output files flags:
#
# 	-oi : output intermediate output file. Defualt :No:
# 	-ospmem <subgraph id>: output members list of a specific subgraphs only
# 	-maxmem <list length>: limit length of members list to 'list length'.
# 		Defualt: 1000
# 	-omat : output matrix format file ('__MAT.txt')
# 	-omet : output metropolis log
# 	-olog : output general log file
# 	-orall : output matrix format of appearances in each random network
# 	-ornet : output random networks files
# 	-otop <no. of top motifs> : No. of top motifs to show
# 	-onodangl: output a list of all nan-dangling detected motifs
#
# 	Other flags
#
# 	-ts : <target,source,weight> Old format of input network file
# 	-q :Quiet mode - No output to the screen
# 	-dd : Don't die mode. Wait to user action before terminating the
# 		program
# 	-pold <num of samples>: run sampling method old version
# 	-nor : Dont search Real network. Defualt :No:
# 	-cr : calculate roles statistics
# Usage : mfinder <Network input file name> -s <motif size> -r <no. of randon networks> [-f <output file name>] [more flags]
#
# 	-s <motif size>  :Motif size to search
# 	-r <rand net num> :Number of random networks to generate
# 	-f <output file name>  : Output file name
# 	-nd : Input network is a non-directed network.
# 	-p <num of samples>: run with Sampling method,
# 	-omem : output members list of all subgraphs
# 	-h : help
#
# 	Additional flags:
#
# 	Motif criteria flags:
# 	-m <value> : mfactor threshold to use when calculating motifs
# 	-z <value> : Z-score threshold to use when calculating motifs
# 	-u : Uniqueness threshold
# 	-nu : Dont count uniqueness and ignore uniqueness threshold
#
# 	Random networks randomization flags:
#
# 	-rs : use stubs method for generating random networks
# 	-rclust : Preserve clustering sequence in random networks
# 	-met :Use Metropolis algorithm to conserve triad-census
# 		in random networks
# 		(for s>3; Default : Do not use Metropolis)
# 	-t0 <(default 0.001)> :Initial temperature (-m0 budstage_Lateral_Mesoderm network motif computing completed
# Muscle
# et option)
# 	-iter <(default 2)> :controls how many steps to perform (-met option)
# 	-eth  <(default 0.005)> : energy threshhold (-met option)
# 	-rgrass <colony size>: generate random networks using grassberger
# 		algorithm
# 	-rgrass_max_sz <max ratio>: Limit maximal colony size ratio
# 	-rdm: don't conserve mutual edges in random networks
# 	-rcl <layers num><size1 size2 ..sizem>: conserve layers in random
# 		 networks
# 	-nsr : Global Switches number when generating Random networks.
#
#
# 	Output files flags:
#
# 	-oi : output intermediate output file. Defualt :No:
# 	-ospmem <subgraph id>: output members list of a specific subgraphs only
# 	-maxmem <list length>: limit length of members list to 'list length'.
# 		Defualt: 1000
# 	-omat : output matrix format file ('__MAT.txt')
# 	-omet : output metropolis log
# 	-olog : output general log file
# 	-orall : output matrix format of appearances in each random network
# 	-ornet : output random networks files
# 	-otop <no. of top motifs> : No. of top motifs to show
# 	-onodangl: output a list of all nan-dangling detected motifs
#
# 	Other flags
#
# 	-ts : <target,source,weight> Old format of input network file
# 	-q :Quiet mode - No output to the screen
# 	-dd : Don't die mode. Wait to user action before terminating the
# 		program
# 	-pold <num of samples>: run sampling method old version
# 	-nor : Dont search Real network. Defualt :No:
# 	-cr : calculate roles statistics
# Usage : mfinder <Network input file name> -s <motif size> -r <no. of randon networks> [-f <output file name>] [more flags]
#
# 	-s <motif size>  :Motif size to search
# 	-r <rand net num> :Number of random networks to generate
# 	-f <output file name>  : Output file name
# 	-nd : Input network is a non-directed network.
# 	-p <num of samples>: run with Sampling method,
# 	-omem : output members list of all subgraphs
# 	-h : help
#
# 	Additional flags:
#
# 	Motif criteria flags:
# 	-m <value> : mfactor threshold to use when calculating motifs
# 	-z <value> : Z-score threshold to use when calculating motifs
# 	-u : Uniqueness threshold
# 	-nu : Dont count uniqueness and ignore uniqueness threshold
#
# 	Random networks randomization flags:
#
# 	-rs : use stubs method for generating random networks
# 	-rclust : Preserve clustering sequence in random networks
# 	-met :Use Metropolis algorithm to conserve triad-census
# 		in random networks
# 		(for s>3; Default : Do not use Metropolis)
# 	-t0 <(default 0.001)> :Initial temperature (-m0 budstage_Muscle network motif computing completed
# NMPs
# et option)
# 	-iter <(default 2)> :controls how many steps to perform (-met option)
# 	-eth  <(default 0.005)> : energy threshhold (-met option)
# 	-rgrass <colony size>: generate random networks using grassberger
# 		algorithm
# 	-rgrass_max_sz <max ratio>: Limit maximal colony size ratio
# 	-rdm: don't conserve mutual edges in random networks
# 	-rcl <layers num><size1 size2 ..sizem>: conserve layers in random
# 		 networks
# 	-nsr : Global Switches number when generating Random networks.
#
#
# 	Output files flags:
#
# 	-oi : output intermediate output file. Defualt :No:
# 	-ospmem <subgraph id>: output members list of a specific subgraphs only
# 	-maxmem <list length>: limit length of members list to 'list length'.
# 		Defualt: 1000
# 	-omat : output matrix format file ('__MAT.txt')
# 	-omet : output metropolis log
# 	-olog : output general log file
# 	-orall : output matrix format of appearances in each random network
# 	-ornet : output random networks files
# 	-otop <no. of top motifs> : No. of top motifs to show
# 	-onodangl: output a list of all nan-dangling detected motifs
#
# 	Other flags
#
# 	-ts : <target,source,weight> Old format of input network file
# 	-q :Quiet mode - No output to the screen
# 	-dd : Don't die mode. Wait to user action before terminating the
# 		program
# 	-pold <num of samples>: run sampling method old version
# 	-nor : Dont search Real network. Defualt :No:
# 	-cr : calculate roles statistics
# Usage : mfinder <Network input file name> -s <motif size> -r <no. of randon networks> [-f <output file name>] [more flags]
#
# 	-s <motif size>  :Motif size to search
# 	-r <rand net num> :Number of random networks to generate
# 	-f <output file name>  : Output file name
# 	-nd : Input network is a non-directed network.
# 	-p <num of samples>: run with Sampling method,
# 	-omem : output members list of all subgraphs
# 	-h : help
#
# 	Additional flags:
#
# 	Motif criteria flags:
# 	-m <value> : mfactor threshold to use when calculating motifs
# 	-z <value> : Z-score threshold to use when calculating motifs
# 	-u : Uniqueness threshold
# 	-nu : Dont count uniqueness and ignore uniqueness threshold
#
# 	Random networks randomization flags:
#
# 	-rs : use stubs method for generating random networks
# 	-rclust : Preserve clustering sequence in random networks
# 	-met :Use Metropolis algorithm to conserve triad-census
# 		in random networks
# 		(for s>3; Default : Do not use Metropolis)
# 	-t0 <(default 0.001)> :Initial temperature (-m0 budstage_NMPs network motif computing completed
# Neural_Anterior
# et option)
# 	-iter <(default 2)> :controls how many steps to perform (-met option)
# 	-eth  <(default 0.005)> : energy threshhold (-met option)
# 	-rgrass <colony size>: generate random networks using grassberger
# 		algorithm
# 	-rgrass_max_sz <max ratio>: Limit maximal colony size ratio
# 	-rdm: don't conserve mutual edges in random networks
# 	-rcl <layers num><size1 size2 ..sizem>: conserve layers in random
# 		 networks
# 	-nsr : Global Switches number when generating Random networks.
#
#
# 	Output files flags:
#
# 	-oi : output intermediate output file. Defualt :No:
# 	-ospmem <subgraph id>: output members list of a specific subgraphs only
# 	-maxmem <list length>: limit length of members list to 'list length'.
# 		Defualt: 1000
# 	-omat : output matrix format file ('__MAT.txt')
# 	-omet : output metropolis log
# 	-olog : output general log file
# 	-orall : output matrix format of appearances in each random network
# 	-ornet : output random networks files
# 	-otop <no. of top motifs> : No. of top motifs to show
# 	-onodangl: output a list of all nan-dangling detected motifs
#
# 	Other flags
#
# 	-ts : <target,source,weight> Old format of input network file
# 	-q :Quiet mode - No output to the screen
# 	-dd : Don't die mode. Wait to user action before terminating the
# 		program
# 	-pold <num of samples>: run sampling method old version
# 	-nor : Dont search Real network. Defualt :No:
# 	-cr : calculate roles statistics
# Usage : mfinder <Network input file name> -s <motif size> -r <no. of randon networks> [-f <output file name>] [more flags]
#
# 	-s <motif size>  :Motif size to search
# 	-r <rand net num> :Number of random networks to generate
# 	-f <output file name>  : Output file name
# 	-nd : Input network is a non-directed network.
# 	-p <num of samples>: run with Sampling method,
# 	-omem : output members list of all subgraphs
# 	-h : help
#
# 	Additional flags:
#
# 	Motif criteria flags:
# 	-m <value> : mfactor threshold to use when calculating motifs
# 	-z <value> : Z-score threshold to use when calculating motifs
# 	-u : Uniqueness threshold
# 	-nu : Dont count uniqueness and ignore uniqueness threshold
#
# 	Random networks randomization flags:
#
# 	-rs : use stubs method for generating random networks
# 	-rclust : Preserve clustering sequence in random networks
# 	-met :Use Metropolis algorithm to conserve triad-census
# 		in random networks
# 		(for s>3; Default : Do not use Metropolis)
# 	-t0 <(default 0.001)> :Initial temperature (-m0 budstage_Neural_Anterior network motif computing completed
# Neural_Crest
# et option)
# 	-iter <(default 2)> :controls how many steps to perform (-met option)
# 	-eth  <(default 0.005)> : energy threshhold (-met option)
# 	-rgrass <colony size>: generate random networks using grassberger
# 		algorithm
# 	-rgrass_max_sz <max ratio>: Limit maximal colony size ratio
# 	-rdm: don't conserve mutual edges in random networks
# 	-rcl <layers num><size1 size2 ..sizem>: conserve layers in random
# 		 networks
# 	-nsr : Global Switches number when generating Random networks.
#
#
# 	Output files flags:
#
# 	-oi : output intermediate output file. Defualt :No:
# 	-ospmem <subgraph id>: output members list of a specific subgraphs only
# 	-maxmem <list length>: limit length of members list to 'list length'.
# 		Defualt: 1000
# 	-omat : output matrix format file ('__MAT.txt')
# 	-omet : output metropolis log
# 	-olog : output general log file
# 	-orall : output matrix format of appearances in each random network
# 	-ornet : output random networks files
# 	-otop <no. of top motifs> : No. of top motifs to show
# 	-onodangl: output a list of all nan-dangling detected motifs
#
# 	Other flags
#
# 	-ts : <target,source,weight> Old format of input network file
# 	-q :Quiet mode - No output to the screen
# 	-dd : Don't die mode. Wait to user action before terminating the
# 		program
# 	-pold <num of samples>: run sampling method old version
# 	-nor : Dont search Real network. Defualt :No:
# 	-cr : calculate roles statistics
# Usage : mfinder <Network input file name> -s <motif size> -r <no. of randon networks> [-f <output file name>] [more flags]
#
# 	-s <motif size>  :Motif size to search
# 	-r <rand net num> :Number of random networks to generate
# 	-f <output file name>  : Output file name
# 	-nd : Input network is a non-directed network.
# 	-p <num of samples>: run with Sampling method,
# 	-omem : output members list of all subgraphs
# 	-h : help
#
# 	Additional flags:
#
# 	Motif criteria flags:
# 	-m <value> : mfactor threshold to use when calculating motifs
# 	-z <value> : Z-score threshold to use when calculating motifs
# 	-u : Uniqueness threshold
# 	-nu : Dont count uniqueness and ignore uniqueness threshold
#
# 	Random networks randomization flags:
#
# 	-rs : use stubs method for generating random networks
# 	-rclust : Preserve clustering sequence in random networks
# 	-met :Use Metropolis algorithm to conserve triad-census
# 		in random networks
# 		(for s>3; Default : Do not use Metropolis)
# 	-t0 <(default 0.001)> :Initial temperature (-m0 budstage_Neural_Crest network motif computing completed
# Neural_Posterior
# et option)
# 	-iter <(default 2)> :controls how many steps to perform (-met option)
# 	-eth  <(default 0.005)> : energy threshhold (-met option)
# 	-rgrass <colony size>: generate random networks using grassberger
# 		algorithm
# 	-rgrass_max_sz <max ratio>: Limit maximal colony size ratio
# 	-rdm: don't conserve mutual edges in random networks
# 	-rcl <layers num><size1 size2 ..sizem>: conserve layers in random
# 		 networks
# 	-nsr : Global Switches number when generating Random networks.
#
#
# 	Output files flags:
#
# 	-oi : output intermediate output file. Defualt :No:
# 	-ospmem <subgraph id>: output members list of a specific subgraphs only
# 	-maxmem <list length>: limit length of members list to 'list length'.
# 		Defualt: 1000
# 	-omat : output matrix format file ('__MAT.txt')
# 	-omet : output metropolis log
# 	-olog : output general log file
# 	-orall : output matrix format of appearances in each random network
# 	-ornet : output random networks files
# 	-otop <no. of top motifs> : No. of top motifs to show
# 	-onodangl: output a list of all nan-dangling detected motifs
#
# 	Other flags
#
# 	-ts : <target,source,weight> Old format of input network file
# 	-q :Quiet mode - No output to the screen
# 	-dd : Don't die mode. Wait to user action before terminating the
# 		program
# 	-pold <num of samples>: run sampling method old version
# 	-nor : Dont search Real network. Defualt :No:
# 	-cr : calculate roles statistics
# Usage : mfinder <Network input file name> -s <motif size> -r <no. of randon networks> [-f <output file name>] [more flags]
#
# 	-s <motif size>  :Motif size to search
# 	-r <rand net num> :Number of random networks to generate
# 	-f <output file name>  : Output file name
# 	-nd : Input network is a non-directed network.
# 	-p <num of samples>: run with Sampling method,
# 	-omem : output members list of all subgraphs
# 	-h : help
#
# 	Additional flags:
#
# 	Motif criteria flags:
# 	-m <value> : mfactor threshold to use when calculating motifs
# 	-z <value> : Z-score threshold to use when calculating motifs
# 	-u : Uniqueness threshold
# 	-nu : Dont count uniqueness and ignore uniqueness threshold
#
# 	Random networks randomization flags:
#
# 	-rs : use stubs method for generating random networks
# 	-rclust : Preserve clustering sequence in random networks
# 	-met :Use Metropolis algorithm to conserve triad-census
# 		in random networks
# 		(for s>3; Default : Do not use Metropolis)
# 	-t0 <(default 0.001)> :Initial temperature (-m0 budstage_Neural_Posterior network motif computing completed
# Notochord
# et option)
# 	-iter <(default 2)> :controls how many steps to perform (-met option)
# 	-eth  <(default 0.005)> : energy threshhold (-met option)
# 	-rgrass <colony size>: generate random networks using grassberger
# 		algorithm
# 	-rgrass_max_sz <max ratio>: Limit maximal colony size ratio
# 	-rdm: don't conserve mutual edges in random networks
# 	-rcl <layers num><size1 size2 ..sizem>: conserve layers in random
# 		 networks
# 	-nsr : Global Switches number when generating Random networks.
#
#
# 	Output files flags:
#
# 	-oi : output intermediate output file. Defualt :No:
# 	-ospmem <subgraph id>: output members list of a specific subgraphs only
# 	-maxmem <list length>: limit length of members list to 'list length'.
# 		Defualt: 1000
# 	-omat : output matrix format file ('__MAT.txt')
# 	-omet : output metropolis log
# 	-olog : output general log file
# 	-orall : output matrix format of appearances in each random network
# 	-ornet : output random networks files
# 	-otop <no. of top motifs> : No. of top motifs to show
# 	-onodangl: output a list of all nan-dangling detected motifs
#
# 	Other flags
#
# 	-ts : <target,source,weight> Old format of input network file
# 	-q :Quiet mode - No output to the screen
# 	-dd : Don't die mode. Wait to user action before terminating the
# 		program
# 	-pold <num of samples>: run sampling method old version
# 	-nor : Dont search Real network. Defualt :No:
# 	-cr : calculate roles statistics
# Usage : mfinder <Network input file name> -s <motif size> -r <no. of randon networks> [-f <output file name>] [more flags]
#
# 	-s <motif size>  :Motif size to search
# 	-r <rand net num> :Number of random networks to generate
# 	-f <output file name>  : Output file name
# 	-nd : Input network is a non-directed network.
# 	-p <num of samples>: run with Sampling method,
# 	-omem : output members list of all subgraphs
# 	-h : help
#
# 	Additional flags:
#
# 	Motif criteria flags:
# 	-m <value> : mfactor threshold to use when calculating motifs
# 	-z <value> : Z-score threshold to use when calculating motifs
# 	-u : Uniqueness threshold
# 	-nu : Dont count uniqueness and ignore uniqueness threshold
#
# 	Random networks randomization flags:
#
# 	-rs : use stubs method for generating random networks
# 	-rclust : Preserve clustering sequence in random networks
# 	-met :Use Metropolis algorithm to conserve triad-census
# 		in random networks
# 		(for s>3; Default : Do not use Metropolis)
# 	-t0 <(default 0.001)> :Initial temperature (-m0 budstage_Notochord network motif computing completed
# PSM
# et option)
# 	-iter <(default 2)> :controls how many steps to perform (-met option)
# 	-eth  <(default 0.005)> : energy threshhold (-met option)
# 	-rgrass <colony size>: generate random networks using grassberger
# 		algorithm
# 	-rgrass_max_sz <max ratio>: Limit maximal colony size ratio
# 	-rdm: don't conserve mutual edges in random networks
# 	-rcl <layers num><size1 size2 ..sizem>: conserve layers in random
# 		 networks
# 	-nsr : Global Switches number when generating Random networks.
#
#
# 	Output files flags:
#
# 	-oi : output intermediate output file. Defualt :No:
# 	-ospmem <subgraph id>: output members list of a specific subgraphs only
# 	-maxmem <list length>: limit length of members list to 'list length'.
# 		Defualt: 1000
# 	-omat : output matrix format file ('__MAT.txt')
# 	-omet : output metropolis log
# 	-olog : output general log file
# 	-orall : output matrix format of appearances in each random network
# 	-ornet : output random networks files
# 	-otop <no. of top motifs> : No. of top motifs to show
# 	-onodangl: output a list of all nan-dangling detected motifs
#
# 	Other flags
#
# 	-ts : <target,source,weight> Old format of input network file
# 	-q :Quiet mode - No output to the screen
# 	-dd : Don't die mode. Wait to user action before terminating the
# 		program
# 	-pold <num of samples>: run sampling method old version
# 	-nor : Dont search Real network. Defualt :No:
# 	-cr : calculate roles statistics
# Usage : mfinder <Network input file name> -s <motif size> -r <no. of randon networks> [-f <output file name>] [more flags]
#
# 	-s <motif size>  :Motif size to search
# 	-r <rand net num> :Number of random networks to generate
# 	-f <output file name>  : Output file name
# 	-nd : Input network is a non-directed network.
# 	-p <num of samples>: run with Sampling method,
# 	-omem : output members list of all subgraphs
# 	-h : help
#
# 	Additional flags:
#
# 	Motif criteria flags:
# 	-m <value> : mfactor threshold to use when calculating motifs
# 	-z <value> : Z-score threshold to use when calculating motifs
# 	-u : Uniqueness threshold
# 	-nu : Dont count uniqueness and ignore uniqueness threshold
#
# 	Random networks randomization flags:
#
# 	-rs : use stubs method for generating random networks
# 	-rclust : Preserve clustering sequence in random networks
# 	-met :Use Metropolis algorithm to conserve triad-census
# 		in random networks
# 		(for s>3; Default : Do not use Metropolis)
# 	-t0 <(default 0.001)> :Initial temperature (-m0 budstage_PSM network motif computing completed
# Somites
# et option)
# 	-iter <(default 2)> :controls how many steps to perform (-met option)
# 	-eth  <(default 0.005)> : energy threshhold (-met option)
# 	-rgrass <colony size>: generate random networks using grassberger
# 		algorithm
# 	-rgrass_max_sz <max ratio>: Limit maximal colony size ratio
# 	-rdm: don't conserve mutual edges in random networks
# 	-rcl <layers num><size1 size2 ..sizem>: conserve layers in random
# 		 networks
# 	-nsr : Global Switches number when generating Random networks.
#
#
# 	Output files flags:
#
# 	-oi : output intermediate output file. Defualt :No:
# 	-ospmem <subgraph id>: output members list of a specific subgraphs only
# 	-maxmem <list length>: limit length of members list to 'list length'.
# 		Defualt: 1000
# 	-omat : output matrix format file ('__MAT.txt')
# 	-omet : output metropolis log
# 	-olog : output general log file
# 	-orall : output matrix format of appearances in each random network
# 	-ornet : output random networks files
# 	-otop <no. of top motifs> : No. of top motifs to show
# 	-onodangl: output a list of all nan-dangling detected motifs
#
# 	Other flags
#
# 	-ts : <target,source,weight> Old format of input network file
# 	-q :Quiet mode - No output to the screen
# 	-dd : Don't die mode. Wait to user action before terminating the
# 		program
# 	-pold <num of samples>: run sampling method old version
# 	-nor : Dont search Real network. Defualt :No:
# 	-cr : calculate roles statistics
# Usage : mfinder <Network input file name> -s <motif size> -r <no. of randon networks> [-f <output file name>] [more flags]
#
# 	-s <motif size>  :Motif size to search
# 	-r <rand net num> :Number of random networks to generate
# 	-f <output file name>  : Output file name
# 	-nd : Input network is a non-directed network.
# 	-p <num of samples>: run with Sampling method,
# 	-omem : output members list of all subgraphs
# 	-h : help
#
# 	Additional flags:
#
# 	Motif criteria flags:
# 	-m <value> : mfactor threshold to use when calculating motifs
# 	-z <value> : Z-score threshold to use when calculating motifs
# 	-u : Uniqueness threshold
# 	-nu : Dont count uniqueness and ignore uniqueness threshold
#
# 	Random networks randomization flags:
#
# 	-rs : use stubs method for generating random networks
# 	-rclust : Preserve clustering sequence in random networks
# 	-met :Use Metropolis algorithm to conserve triad-census
# 		in random networks
# 		(for s>3; Default : Do not use Metropolis)
# 	-t0 <(default 0.001)> :Initial temperature (-m0 budstage_Somites network motif computing completed
# unassigned
# et option)
# 	-iter <(default 2)> :controls how many steps to perform (-met option)
# 	-eth  <(default 0.005)> : energy threshhold (-met option)
# 	-rgrass <colony size>: generate random networks using grassberger
# 		algorithm
# 	-rgrass_max_sz <max ratio>: Limit maximal colony size ratio
# 	-rdm: don't conserve mutual edges in random networks
# 	-rcl <layers num><size1 size2 ..sizem>: conserve layers in random
# 		 networks
# 	-nsr : Global Switches number when generating Random networks.
#
#
# 	Output files flags:
#
# 	-oi : output intermediate output file. Defualt :No:
# 	-ospmem <subgraph id>: output members list of a specific subgraphs only
# 	-maxmem <list length>: limit length of members list to 'list length'.
# 		Defualt: 1000
# 	-omat : output matrix format file ('__MAT.txt')
# 	-omet : output metropolis log
# 	-olog : output general log file
# 	-orall : output matrix format of appearances in each random network
# 	-ornet : output random networks files
# 	-otop <no. of top motifs> : No. of top motifs to show
# 	-onodangl: output a list of all nan-dangling detected motifs
#
# 	Other flags
#
# 	-ts : <target,source,weight> Old format of input network file
# 	-q :Quiet mode - No output to the screen
# 	-dd : Don't die mode. Wait to user action before terminating the
# 		program
# 	-pold <num of samples>: run sampling method old version
# 	-nor : Dont search Real network. Defualt :No:
# 	-cr : calculate roles statistics
# Usage : mfinder <Network input file name> -s <motif size> -r <no. of randon networks> [-f <output file name>] [more flags]
#
# 	-s <motif size>  :Motif size to search
# 	-r <rand net num> :Number of random networks to generate
# 	-f <output file name>  : Output file name
# 	-nd : Input network is a non-directed network.
# 	-p <num of samples>: run with Sampling method,
# 	-omem : output members list of all subgraphs
# 	-h : help
#
# 	Additional flags:
#
# 	Motif criteria flags:
# 	-m <value> : mfactor threshold to use when calculating motifs
# 	-z <value> : Z-score threshold to use when calculating motifs
# 	-u : Uniqueness threshold
# 	-nu : Dont count uniqueness and ignore uniqueness threshold
#
# 	Random networks randomization flags:
#
# 	-rs : use stubs method for generating random networks
# 	-rclust : Preserve clustering sequence in random networks
# 	-met :Use Metropolis algorithm to conserve triad-census
# 		in random networks
# 		(for s>3; Default : Do not use Metropolis)
# 	-t0 <(default 0.001)> :Initial temperature (-m0 budstage_unassigned network motif computing completed
# et option)
# 	-iter <(default 2)> :controls how many steps to perform (-met option)
# 	-eth  <(default 0.005)> : energy threshhold (-met option)
# 	-rgrass <colony size>: generate random networks using grassberger
# 		algorithm
# 	-rgrass_max_sz <max ratio>: Limit maximal colony size ratio
# 	-rdm: don't conserve mutual edges in random networks
# 	-rcl <layers num><size1 size2 ..sizem>: conserve layers in random
# 		 networks
# 	-nsr : Global Switches number when generating Random networks.
#
#
# 	Output files flags:
#
# 	-oi : output intermediate output file. Defualt :No:
# 	-ospmem <subgraph id>: output members list of a specific subgraphs only
# 	-maxmem <list length>: limit length of members list to 'list length'.
# 		Defualt: 1000
# 	-omat : output matrix format file ('__MAT.txt')
# 	-omet : output metropolis log
# 	-olog : output general log file
# 	-orall : output matrix format of appearances in each random network
# 	-ornet : output random networks files
# 	-otop <no. of top motifs> : No. of top motifs to show
# 	-onodangl: output a list of all nan-dangling detected motifs
#
# 	Other flags
#
# 	-ts : <target,source,weight> Old format of input network file
# 	-q :Quiet mode - No output to the screen
# 	-dd : Don't die mode. Wait to user action before terminating the
# 		program
# 	-pold <num of samples>: run sampling method old version
# 	-nor : Dont search Real network. Defualt :No:
# 	-cr : calculate roles statistics
# Differentiating_Neurons
# Input Network file is filtered_GRN_5somite_Differentiating_Neurons_mfinder_format.txt
# mfinder Version 1.20
#
# Loading Network
# 	Reading Network file in <Source,Target,Weight> Format
# Searching motifs size 3
# Processing Real network...
#
#  (Real network processing runtime was:    0.0 seconds.)
# Processing Random networks
# ..........
#  Estimated run time left :     27 seconds.
#
# ..........
#  Estimated run time left :     24 seconds.
#
# ..........
#  Estimated run time left :     21 seconds.
#
# ..........
#  Estimated run time left :     18 seconds.
#
# ..........
#  Estimated run time left :     16 seconds.
#
# ..........
#  Estimated run time left :     13 seconds.
#
# ..........
#  Estimated run time left :      9 seconds.
#
# ..........
#  Estimated run time left :      6 seconds.
#
# ..........
#  Estimated run time left :      3 seconds.
#
# ..........
#  Estimated run time left :      0 seconds.
#
#
# Calculating Results...
#
# MOTIF FINDER RESULTS:
#
# 	Network name: filtered_GRN_5somite_Differentiating_Neurons_mfinder_format.txt
# 	Network 5somite_Differentiating_Neurons network motif computing completed
# Endoderm
# type: Directed
# 	Num of Nodes: 421 Num of Edges: 2000
# 	Num of Nodes with edges: 421
# 	Maximal out degree (out-hub) : 51
# 	Maximal in degree (in-hub) : 55
# 	Roots num: 137 Leaves num: 199
# 	Single Edges num: 1826 Mutual Edges num: 85
#
# 	Motif size searched  3
# 	Total number of 3-node subgraphs : 34760
# 	Number of random networks generated : 100
# 	Random networks generation method: Switches
# 	Num of Switches range: 100.0-200.0, Success switches Ratio:0.711+-0.01
#
# The following motifs were found:
#
# Criteria taken : Nreal Zscore > 2.00
#                  Pval ignored (due to small number of random networks)
#                  Mfactor > 1.10
#                  Uniqueness >= 4
#
#
#
# 	Full list includes 5 motifs
#
# MOTIF	NREAL	NRAND		NREAL	NREAL	UNIQ	CREAL
# ID		STATS		ZSCORE	PVAL	VAL	[MILI]
#
# 38	1167	707.9+-36.3	12.64	0.000	30	33.57
#
# 0 1 1
# 0 0 1
# 0 0 0
#
# 46	347	152.6+-14.9	13.04	0.000	12	9.98
#
# 0 1 1
# 1 0 1
# 0 0 0
#
# 108	174	47.9+-8.2	15.38	0.000	10	5.01
#
# 0 0 1
# 1 0 1
# 1 0 0
#
# 110	93	42.1+-6.9	7.39	0.000	8	2.68
#
# 0 1 1
# 1 0 1
# 1 0 0
#
# 238	50	10.9+-2.7	14.25	0.000	7	1.44
#
# 0 1 1
# 1 0 1
# 1 1 0
#
#
#
#  (Application total runtime was:   32.0 seconds.)
#
#  (Real network processing runtime was:    0.0 seconds.)
#
#  (Single Random network processing runtime was:    0.3 seconds.)
#
# Output File motifs_5somite_Differentiating_Neurons_OUT.txt was generated
# Input Network file is filtered_GRN_5somite_Endoderm_mfinder_format.txt
# mfinder Version 1.20
#
# Loading Network
# 	Reading Network file in <Source,Target,Weight> Format
# Searching motifs size 3
# Processing Real network...
#
#  (Real network processing runtime was:    0.0 seconds.)
# Processing Random networks
# ..........
#  Estimated run time left :     27 seconds.
#
# ..........
#  Estimated run time left :     24 seconds.
#
# ..........
#  Estimated run time left :     21 seconds.
#
# ..........
#  Estimated run time left :     18 seconds.
#
# ..........
#  Estimated run time left :     15 seconds.
#
# ..........
#  Estimated run time left :     12 seconds.
#
# ..........
#  Estimated run time left :      9 seconds.
#
# ..........
#  Estimated run time left :      6 seconds.
#
# ..........
#  Estimated run time left :      3 seconds.
#
# ..........
#  Estimated run time left :      0 seconds.
#
#
# Calculating Results...
#
# MOTIF FINDER RESULTS:
#
# 	Network name: filtered_GRN_5somite_Endoderm_mfinder_format.txt
# 	Network type: Directed
# 	Num of Nodes: 5somite_Endoderm network motif computing completed
# Epidermal
# 457 Num of Edges: 2000
# 	Num of Nodes with edges: 457
# 	Maximal out degree (out-hub) : 51
# 	Maximal in degree (in-hub) : 36
# 	Roots num: 163 Leaves num: 213
# 	Single Edges num: 1888 Mutual Edges num: 44
#
# 	Motif size searched  3
# 	Total number of 3-node subgraphs : 31268
# 	Number of random networks generated : 100
# 	Random networks generation method: Switches
# 	Num of Switches range: 100.0-200.0, Success switches Ratio:0.764+-0.00
#
# The following motifs were found:
#
# Criteria taken : Nreal Zscore > 2.00
#                  Pval ignored (due to small number of random networks)
#                  Mfactor > 1.10
#                  Uniqueness >= 4
#
#
#
# 	Full list includes 4 motifs
#
# MOTIF	NREAL	NRAND		NREAL	NREAL	UNIQ	CREAL
# ID		STATS		ZSCORE	PVAL	VAL	[MILI]
#
# 38	1081	502.1+-26.7	21.67	0.000	33	34.57
#
# 0 1 1
# 0 0 1
# 0 0 0
#
# 46	156	32.9+-7.3	16.92	0.000	10	4.99
#
# 0 1 1
# 1 0 1
# 0 0 0
#
# 108	127	28.7+-5.8	16.94	0.000	8	4.06
#
# 0 0 1
# 1 0 1
# 1 0 0
#
# 110	49	12.9+-3.8	9.51	0.000	7	1.57
#
# 0 1 1
# 1 0 1
# 1 0 0
#
#
#
#  (Application total runtime was:   31.0 seconds.)
#
#  (Real network processing runtime was:    0.0 seconds.)
#
#  (Single Random network processing runtime was:    0.3 seconds.)
#
# Output File motifs_5somite_Endoderm_OUT.txt was generated
# Input Network file is filtered_GRN_5somite_Epidermal_mfinder_format.txt
# mfinder Version 1.20
#
# Loading Network
# 	Reading Network file in <Source,Target,Weight> Format
# Searching motifs size 3
# Processing Real network...
#
#  (Real network processing runtime was:    0.0 seconds.)
# Processing Random networks
# ..........
#  Estimated run time left :     27 seconds.
#
# ..........
#  Estimated run time left :     24 seconds.
#
# ..........
#  Estimated run time left :     23 seconds.
#
# ..........
#  Estimated run time left :     20 seconds.
#
# ..........
#  Estimated run time left :     16 seconds.
#
# ..........
#  Estimated run time left :     13 seconds.
#
# ..........
#  Estimated run time left :     10 seconds.
#
# ..........
#  Estimated run time left :      6 seconds.
#
# ..........
#  Estimated run time left :      3 seconds.
#
# ..........
#  Estimated run time left :      0 seconds.
#
#
# Calculating Results...
#
# MOTIF FINDER RESULTS:
#
# 	Network name: filtered_GRN_5somite_Epidermal_mfinder_format.txt
# 	Network type: Directed
# 	Num of Nodes: 473 Num of Edges: 2000
# 	Num of Nodes with edges: 473
# 	Maximal out degree (out-hub) : 53
# 	Maximal in degree (in-hub) : 51
# 	Roots num: 140 Leaves num: 246
# 	Single Edges num: 1861 Mutual Edges num: 69
#
# 	Motif size searched  3
# 	Total number of 3-node subgraphs : 36099
# 	Number of random networks generated : 100
# 	Random networks generation method: Switches
# 	Num of Switches range: 100.0-200.0, Success switches Ratio:0.722+-0.00
#
# The following motifs were found:
#
# Criteria taken : Nreal Zscore > 2.00
#                  Pval ignored (due to small number of random networks)
#                  Mfactor > 1.10
#                  Uniqueness >= 4
#
#
#
# 	Full list includes 6 motifs
#
# MOTIF	NREAL	NRAND		NREAL	NREAL	UNIQ	CREAL
# ID		STATS		ZSCORE	PVAL	VAL	[MILI]
#
# 38	876	689.8+-37.8	4.93	0.000	29	24.27
#
# 0 1 1
# 0 0 1
# 0 0 0
#
# 46	310	174.1+-14.8	9.17	0.000	19	8.59
#
# 0 1 1
# 1 0 1
# 0 0 0
#
# 102	40	19.8+-4.5	4.50	0.000	11	1.11
#
# 0 1 1
# 0 0 1
# 1 0 0
#
# 108	43	17.2+-4.5	5.77	0.000	7	1.19
#
# 0 0 1
# 1 0 1
# 1 0 0
#
# 110	59	19.0+-45somite_Epidermal network motif computing completed
# Lateral_Mesoderm
# .4	9.16	0.000	8	1.63
#
# 0 1 1
# 1 0 1
# 1 0 0
#
# 238	15	3.4+-1.8	6.47	0.000	5	0.42
#
# 0 1 1
# 1 0 1
# 1 1 0
#
#
#
#  (Application total runtime was:   33.0 seconds.)
#
#  (Real network processing runtime was:    0.0 seconds.)
#
#  (Single Random network processing runtime was:    0.3 seconds.)
#
# Output File motifs_5somite_Epidermal_OUT.txt was generated
# Input Network file is filtered_GRN_5somite_Lateral_Mesoderm_mfinder_format.txt
# mfinder Version 1.20
#
# Loading Network
# 	Reading Network file in <Source,Target,Weight> Format
# Searching motifs size 3
# Processing Real network...
#
#  (Real network processing runtime was:    0.0 seconds.)
# Processing Random networks
# ..........
#  Estimated run time left :     36 seconds.
#
# ..........
#  Estimated run time left :     28 seconds.
#
# ..........
#  Estimated run time left :     26 seconds.
#
# ..........
#  Estimated run time left :     21 seconds.
#
# ..........
#  Estimated run time left :     17 seconds.
#
# ..........
#  Estimated run time left :     14 seconds.
#
# ..........
#  Estimated run time left :     10 seconds.
#
# ..........
#  Estimated run time left :      7 seconds.
#
# ..........
#  Estimated run time left :      4 seconds.
#
# ..........
#  Estimated run time left :      0 seconds.
#
#
# Calculating Results...
#
# MOTIF FINDER RESULTS:
#
# 	Network name: filtered_GRN_5somite_Lateral_Mesoderm_mfinder_format.txt
# 	Network type: Directed5somite_Lateral_Mesoderm network motif computing completed
# Muscle
#
# 	Num of Nodes: 466 Num of Edges: 2000
# 	Num of Nodes with edges: 466
# 	Maximal out degree (out-hub) : 64
# 	Maximal in degree (in-hub) : 49
# 	Roots num: 133 Leaves num: 237
# 	Single Edges num: 1873 Mutual Edges num: 61
#
# 	Motif size searched  3
# 	Total number of 3-node subgraphs : 39597
# 	Number of random networks generated : 100
# 	Random networks generation method: Switches
# 	Num of Switches range: 100.0-200.0, Success switches Ratio:0.710+-0.00
#
# The following motifs were found:
#
# Criteria taken : Nreal Zscore > 2.00
#                  Pval ignored (due to small number of random networks)
#                  Mfactor > 1.10
#                  Uniqueness >= 4
#
#
#
# 	Full list includes 4 motifs
#
# MOTIF	NREAL	NRAND		NREAL	NREAL	UNIQ	CREAL
# ID		STATS		ZSCORE	PVAL	VAL	[MILI]
#
# 38	1080	938.9+-44.6	3.16	0.000	29	27.27
#
# 0 1 1
# 0 0 1
# 0 0 0
#
# 46	288	141.8+-12.9	11.29	0.000	17	7.27
#
# 0 1 1
# 1 0 1
# 0 0 0
#
# 108	67	26.2+-6.0	6.84	0.000	9	1.69
#
# 0 0 1
# 1 0 1
# 1 0 0
#
# 110	48	21.9+-5.0	5.19	0.000	6	1.21
#
# 0 1 1
# 1 0 1
# 1 0 0
#
#
#
#  (Application total runtime was:   35.0 seconds.)
#
#  (Real network processing runtime was:    0.0 seconds.)
#
#  (Single Random network processing runtime was:    0.3 seconds.)
#
# Output File motifs_5somite_Lateral_Mesoderm_OUT.txt was generated
# Input Network file is filtered_GRN_5somite_Muscle_mfinder_format.txt
# mfinder Version 1.20
#
# Loading Network
# 	Reading Network file in <Source,Target,Weight> Format
# Searching motifs size 3
# Processing Real network...
#
#  (Real network processing runtime was:    0.0 seconds.)
# Processing Random networks
# ..........
#  Estimated run time left :     27 seconds.
#
# ..........
#  Estimated run time left :     28 seconds.
#
# ..........
#  Estimated run time left :     23 seconds.
#
# ..........
#  Estimated run time left :     21 seconds.
#
# ..........
#  Estimated run time left :     18 seconds.
#
# ..........
#  Estimated run time left :     14 seconds.
#
# ..........
#  Estimated run time left :     11 seconds.
#
# ..........
#  Estimated run time left :      7 seconds.
#
# ..........
#  Estimated run time left :      4 seconds.
#
# ..........
#  Estimated run time left :      0 seconds.
#
#
# Calculating Results...
#
# MOTIF FINDER RESULTS:
#
# 	Network name: filtered_GRN_5somite_Muscle_mfinder_format.txt
# 	Network type: Directed
# 	Num of Nodes: 364 5somite_Muscle network motif computing completed
# NMPs
# Num of Edges: 2000
# 	Num of Nodes with edges: 364
# 	Maximal out degree (out-hub) : 76
# 	Maximal in degree (in-hub) : 41
# 	Roots num: 119 Leaves num: 193
# 	Single Edges num: 1876 Mutual Edges num: 61
#
# 	Motif size searched  3
# 	Total number of 3-node subgraphs : 44901
# 	Number of random networks generated : 100
# 	Random networks generation method: Switches
# 	Num of Switches range: 100.0-200.0, Success switches Ratio:0.603+-0.01
#
# The following motifs were found:
#
# Criteria taken : Nreal Zscore > 2.00
#                  Pval ignored (due to small number of random networks)
#                  Mfactor > 1.10
#                  Uniqueness >= 4
#
#
#
# 	Full list includes 5 motifs
#
# MOTIF	NREAL	NRAND		NREAL	NREAL	UNIQ	CREAL
# ID		STATS		ZSCORE	PVAL	VAL	[MILI]
#
# 38	1730	1378.9+-62.3	5.64	0.000	22	38.53
#
# 0 1 1
# 0 0 1
# 0 0 0
#
# 46	570	306.6+-19.2	13.69	0.000	12	12.69
#
# 0 1 1
# 1 0 1
# 0 0 0
#
# 108	120	63.9+-8.7	6.44	0.000	8	2.67
#
# 0 0 1
# 1 0 1
# 1 0 0
#
# 110	89	60.7+-9.2	3.09	0.000	5	1.98
#
# 0 1 1
# 1 0 1
# 1 0 0
#
# 238	39	18.3+-2.8	7.27	0.000	4	0.87
#
# 0 1 1
# 1 0 1
# 1 1 0
#
#
#
#  (Application total runtime was:   36.0 seconds.)
#
#  (Real network processing runtime was:    0.0 seconds.)
#
#  (Single Random network processing runtime was:    0.4 seconds.)
#
# Output File motifs_5somite_Muscle_OUT.txt was generated
# Input Network file is filtered_GRN_5somite_NMPs_mfinder_format.txt
# mfinder Version 1.20
#
# Loading Network
# 	Reading Network file in <Source,Target,Weight> Format
# Searching motifs size 3
# Processing Real network...
#
#  (Real network processing runtime was:    0.0 seconds.)
# Processing Random networks
# ..........
#  Estimated run time left :     27 seconds.
#
# ..........
#  Estimated run time left :     28 seconds.
#
# ..........
#  Estimated run time left :     23 seconds.
#
# ..........
#  Estimated run time left :     21 seconds.
#
# ..........
#  Estimated run time left :     18 seconds.
#
# ..........
#  Estimated run time left :     14 seconds.
#
# ..........
#  Estimated run time left :     11 seconds.
#
# ..........
#  Estimated run time left :      7 seconds.
#
# ..........
#  Estimated run time left :      4 seconds.
#
# ..........
#  Estimated run time left :      0 seconds.
#
#
# Calculating Results...
#
# MOTIF FINDER RESULTS:
#
# 	Network name: filtered_GRN_5somite_NMPs_mfinder_format.txt
# 	Network type: Directed
# 	Num of Nodes: 390 Num 5somite_NMPs network motif computing completed
# Neural_Anterior
# of Edges: 2000
# 	Num of Nodes with edges: 390
# 	Maximal out degree (out-hub) : 70
# 	Maximal in degree (in-hub) : 44
# 	Roots num: 120 Leaves num: 201
# 	Single Edges num: 1871 Mutual Edges num: 64
#
# 	Motif size searched  3
# 	Total number of 3-node subgraphs : 43797
# 	Number of random networks generated : 100
# 	Random networks generation method: Switches
# 	Num of Switches range: 100.0-200.0, Success switches Ratio:0.625+-0.01
#
# The following motifs were found:
#
# Criteria taken : Nreal Zscore > 2.00
#                  Pval ignored (due to small number of random networks)
#                  Mfactor > 1.10
#                  Uniqueness >= 4
#
#
#
# 	Full list includes 4 motifs
#
# MOTIF	NREAL	NRAND		NREAL	NREAL	UNIQ	CREAL
# ID		STATS		ZSCORE	PVAL	VAL	[MILI]
#
# ...
#
# 38	1899	1186.8+-68.6	10.38	0.000	22	36.88
#
# 0 1 1
# 0 0 1
# 0 0 0
#
# 46	392	208.9+-22.2	8.23	0.000	9	7.61
#
# 0 1 1
# 1 0 1
# 0 0 0
#
# 108	71	31.7+-6.0	6.53	0.000	7	1.38
#
# 0 0 1
# 1 0 1
# 1 0 0
#
#
#
#  (Application total runtime was:   40.0 seconds.)
#
#  (Real network processing runtime was:    0.0 seconds.)
#
#  (Single Random network processing runtime was:    0.4 seconds.)
#
# Output File motifs_20somite_Muscle_OUT.txt was generated
# Input Network file is filtered_GRN_20somite_NMPs_mfinder_format.txt
# mfinder Version 1.20
#
# Loading Network
# 	Reading Network file in <Source,Target,Weight> Format
# Searching motifs size 3
# Processing Real network...
#
#  (Real network processing runtime was:    0.0 seconds.)
# Processing Random networks
# ..........
#  Estimated run time left :     27 seconds.
#
# ..........
#  Estimated run time left :     28 seconds.
#
# ..........
#  Estimated run time left :     23 seconds.
#
# ..........
#  Estimated run time left :     20 seconds.
#
# ..........
#  Estimated run time left :     17 seconds.
#
# ..........
#  Estimated run time left :     13 seconds.
#
# ..........
#  Estimated run time left :     10 seconds.
#
# ..........
#  Estimated run time left :      7 seconds.
#
# ..........
#  Estimated run time left :      4 seconds.
#
# ..........
#  Estimated run time left :      0 seconds.
#
#
# Calculating Results...
#
# MOTIF FINDER RESULTS:
#
# 	Network name: filtered_GRN_20somite_NMPs_mfinder_format.txt
# 	Network type: Directed
# 	Num of Nodes: 468 Nu20somite_NMPs network motif computing completed
# Neural_Anterior
# m of Edges: 2000
# 	Num of Nodes with edges: 468
# 	Maximal out degree (out-hub) : 88
# 	Maximal in degree (in-hub) : 30
# 	Roots num: 121 Leaves num: 282
# 	Single Edges num: 1959 Mutual Edges num: 20
#
# 	Motif size searched  3
# 	Total number of 3-node subgraphs : 43431
# 	Number of random networks generated : 100
# 	Random networks generation method: Switches
# 	Num of Switches range: 100.0-200.0, Success switches Ratio:0.666+-0.00
#
# The following motifs were found:
#
# Criteria taken : Nreal Zscore > 2.00
#                  Pval ignored (due to small number of random networks)
#                  Mfactor > 1.10
#                  Uniqueness >= 4
#
#
#
# 	Full list includes 3 motifs
#
# MOTIF	NREAL	NRAND		NREAL	NREAL	UNIQ	CREAL
# ID		STATS		ZSCORE	PVAL	VAL	[MILI]
#
# 38	1549	752.0+-46.1	17.29	0.000	25	35.67
#
# 0 1 1
# 0 0 1
# 0 0 0
#
# 46	270	102.1+-13.7	12.23	0.000	5	6.22
#
# 0 1 1
# 1 0 1
# 0 0 0
#
# 108	43	23.6+-4.9	3.97	0.000	6	0.99
#
# 0 0 1
# 1 0 1
# 1 0 0
#
#
#
#  (Application total runtime was:   35.0 seconds.)
#
#  (Real network processing runtime was:    0.0 seconds.)
#
#  (Single Random network processing runtime was:    0.3 seconds.)
#
# Output File motifs_20somite_NMPs_OUT.txt was generated
# Input Network file is filtered_GRN_20somite_Neural_Anterior_mfinder_format.txt
# mfinder Version 1.20
#
# Loading Network
# 	Reading Network file in <Source,Target,Weight> Format
# Searching motifs size 3
# Processing Real network...
#
#  (Real network processing runtime was:    0.0 seconds.)
# Processing Random networks
# ..........
#  Estimated run time left :     36 seconds.
#
# ..........
#  Estimated run time left :     28 seconds.
#
# ..........
#  Estimated run time left :     23 seconds.
#
# ..........
#  Estimated run time left :     20 seconds.
#
# ..........
#  Estimated run time left :     17 seconds.
#
# ..........
#  Estimated run time left :     13 seconds.
#
# ..........
#  Estimated run time left :     10 seconds.
#
# ..........
#  Estimated run time left :      7 seconds.
#
# ..........
#  Estimated run time left :      3 seconds.
#
# ..........
#  Estimated run time left :      0 seconds.
#
#
# Calculating Results...
#
# MOTIF FINDER RESULTS:
#
# 	Network name: filtered_GRN_20somite_Neural_Anterior_mfinder_format.txt
# 	Network type: Directed20somite_Neural_Anterior network motif computing completed
# Neural_Crest
#
# 	Num of Nodes: 463 Num of Edges: 2000
# 	Num of Nodes with edges: 463
# 	Maximal out degree (out-hub) : 78
# 	Maximal in degree (in-hub) : 84
# 	Roots num: 179 Leaves num: 201
# 	Single Edges num: 1901 Mutual Edges num: 49
#
# 	Motif size searched  3
# 	Total number of 3-node subgraphs : 46496
# 	Number of random networks generated : 100
# 	Random networks generation method: Switches
# 	Num of Switches range: 100.0-200.0, Success switches Ratio:0.610+-0.00
#
# The following motifs were found:
#
# Criteria taken : Nreal Zscore > 2.00
#                  Pval ignored (due to small number of random networks)
#                  Mfactor > 1.10
#                  Uniqueness >= 4
#
#
#
# 	Full list includes 2 motifs
#
# MOTIF	NREAL	NRAND		NREAL	NREAL	UNIQ	CREAL
# ID		STATS		ZSCORE	PVAL	VAL	[MILI]
#
# 46	261	213.7+-14.7	3.23	0.000	15	5.61
#
# 0 1 1
# 1 0 1
# 0 0 0
#
# 110	26	10.7+-2.8	5.39	0.000	7	0.56
#
# 0 1 1
# 1 0 1
# 1 0 0
#
#
#
#  (Application total runtime was:   34.0 seconds.)
#
#  (Real network processing runtime was:    0.0 seconds.)
#
#  (Single Random network processing runtime was:    0.3 seconds.)
#
# Output File motifs_20somite_Neural_Anterior_OUT.txt was generated
# Input Network file is filtered_GRN_20somite_Neural_Crest_mfinder_format.txt
# mfinder Version 1.20
#
# Loading Network
# 	Reading Network file in <Source,Target,Weight> Format
# Searching motifs size 3
# Processing Real network...
#
#  (Real network processing runtime was:    0.0 seconds.)
# Processing Random networks
# ..........
#  Estimated run time left :     27 seconds.
#
# ..........
#  Estimated run time left :     24 seconds.
#
# ..........
#  Estimated run time left :     23 seconds.
#
# ..........
#  Estimated run time left :     20 seconds.
#
# ..........
#  Estimated run time left :     16 seconds.
#
# ..........
#  Estimated run time left :     13 seconds.
#
# ..........
#  Estimated run time left :     10 seconds.
#
# ..........
#  Estimated run time left :      6 seconds.
#
# ..........
#  Estimated run time left :      3 seconds.
#
# ..........
#  Estimated run time left :      0 seconds.
#
#
# Calculating Results...
#
# MOTIF FINDER RESULTS:
#
# 	Network name: filtered_GRN_20somite_Neural_Crest_mfinder_format.txt
# 	Network type: Directed
# 	Num 20somite_Neural_Crest network motif computing completed
# Neural_Posterior
# of Nodes: 424 Num of Edges: 2000
# 	Num of Nodes with edges: 424
# 	Maximal out degree (out-hub) : 76
# 	Maximal in degree (in-hub) : 61
# 	Roots num: 120 Leaves num: 229
# 	Single Edges num: 1907 Mutual Edges num: 45
#
# 	Motif size searched  3
# 	Total number of 3-node subgraphs : 41690
# 	Number of random networks generated : 100
# 	Random networks generation method: Switches
# 	Num of Switches range: 100.0-200.0, Success switches Ratio:0.655+-0.00
#
# The following motifs were found:
#
# Criteria taken : Nreal Zscore > 2.00
#                  Pval ignored (due to small number of random networks)
#                  Mfactor > 1.10
#                  Uniqueness >= 4
#
#
#
# 	Full list includes 4 motifs
#
# MOTIF	NREAL	NRAND		NREAL	NREAL	UNIQ	CREAL
# ID		STATS		ZSCORE	PVAL	VAL	[MILI]
#
# 38	1223	872.8+-40.3	8.70	0.000	30	29.34
#
# 0 1 1
# 0 0 1
# 0 0 0
#
# 46	355	212.5+-16.4	8.68	0.000	13	8.52
#
# 0 1 1
# 1 0 1
# 0 0 0
#
# 108	55	19.1+-5.0	7.23	0.000	10	1.32
#
# 0 0 1
# 1 0 1
# 1 0 0
#
# 110	36	16.2+-3.9	5.14	0.000	6	0.86
#
# 0 1 1
# 1 0 1
# 1 0 0
#
#
#
#  (Application total runtime was:   33.0 seconds.)
#
#  (Real network processing runtime was:    0.0 seconds.)
#
#  (Single Random network processing runtime was:    0.3 seconds.)
#
# Output File motifs_20somite_Neural_Crest_OUT.txt was generated
# Input Network file is filtered_GRN_20somite_Neural_Posterior_mfinder_format.txt
# mfinder Version 1.20
#
# Loading Network
# 	Reading Network file in <Source,Target,Weight> Format
# Searching motifs size 3
# Processing Real network...
#
#  (Real network processing runtime was:    0.0 seconds.)
# Processing Random networks
# ..........
#  Estimated run time left :     36 seconds.
#
# ..........
#  Estimated run time left :     28 seconds.
#
# ..........
#  Estimated run time left :     23 seconds.
#
# ..........
#  Estimated run time left :     20 seconds.
#
# ..........
#  Estimated run time left :     16 seconds.
#
# ..........
#  Estimated run time left :     13 seconds.
#
# ..........
#  Estimated run time left :     10 seconds.
#
# ..........
#  Estimated run time left :      6 seconds.
#
# ..........
#  Estimated run time left :      3 seconds.
#
# ..........
#  Estimated run time left :      0 seconds.
#
#
# Calculating Results...
#
# MOTIF FINDER RESULTS:
#
# 	Network name: filtered_GRN_20somite_Neural_Posterior_mfinder_format.txt
# 	Network type: Direct20somite_Neural_Posterior network motif computing completed
# Notochord
# ed
# 	Num of Nodes: 453 Num of Edges: 2000
# 	Num of Nodes with edges: 453
# 	Maximal out degree (out-hub) : 56
# 	Maximal in degree (in-hub) : 89
# 	Roots num: 179 Leaves num: 190
# 	Single Edges num: 1879 Mutual Edges num: 59
#
# 	Motif size searched  3
# 	Total number of 3-node subgraphs : 43149
# 	Number of random networks generated : 100
# 	Random networks generation method: Switches
# 	Num of Switches range: 100.0-200.0, Success switches Ratio:0.643+-0.00
#
# The following motifs were found:
#
# Criteria taken : Nreal Zscore > 2.00
#                  Pval ignored (due to small number of random networks)
#                  Mfactor > 1.10
#                  Uniqueness >= 4
#
#
#
# 	Full list includes 4 motifs
#
# MOTIF	NREAL	NRAND		NREAL	NREAL	UNIQ	CREAL
# ID		STATS		ZSCORE	PVAL	VAL	[MILI]
#
# 46	361	292.5+-17.0	4.02	0.000	17	8.37
#
# 0 1 1
# 1 0 1
# 0 0 0
#
# 98	16	7.0+-3.1	2.89	0.010	6	0.37
#
# 0 1 0
# 0 0 1
# 1 0 0
#
# 108	25	12.2+-3.7	3.48	0.010	8	0.58
#
# 0 0 1
# 1 0 1
# 1 0 0
#
# 110	38	17.3+-3.8	5.42	0.000	8	0.88
#
# 0 1 1
# 1 0 1
# 1 0 0
#
#
#
#  (Application total runtime was:   33.0 seconds.)
#
#  (Real network processing runtime was:    0.0 seconds.)
#
#  (Single Random network processing runtime was:    0.3 seconds.)
#
# Output File motifs_20somite_Neural_Posterior_OUT.txt was generated
# Input Network file is filtered_GRN_20somite_Notochord_mfinder_format.txt
# mfinder Version 1.20
#
# Loading Network
# 	Reading Network file in <Source,Target,Weight> Format
# Searching motifs size 3
# Processing Real network...
#
#  (Real network processing runtime was:    0.0 seconds.)
# Processing Random networks
# ..........
#  Estimated run time left :     36 seconds.
#
# ..........
#  Estimated run time left :     28 seconds.
#
# ..........
#  Estimated run time left :     23 seconds.
#
# ..........
#  Estimated run time left :     21 seconds.
#
# ..........
#  Estimated run time left :     17 seconds.
#
# ..........
#  Estimated run time left :     14 seconds.
#
# ..........
#  Estimated run time left :     10 seconds.
#
# ..........
#  Estimated run time left :      7 seconds.
#
# ..........
#  Estimated run time left :      3 seconds.
#
# ..........
#  Estimated run time left :      0 seconds.
#
#
# Calculating Results...
#
# MOTIF FINDER RESULTS:
#
# 	Network name: filtered_GRN_20somite_Notochord_mfinder_format.txt
# 	Network type: Directed
# 	Num of Nod20somite_Notochord network motif computing completed
# PSM
# es: 477 Num of Edges: 2000
# 	Num of Nodes with edges: 477
# 	Maximal out degree (out-hub) : 120
# 	Maximal in degree (in-hub) : 32
# 	Roots num: 130 Leaves num: 284
# 	Single Edges num: 1961 Mutual Edges num: 16
#
# 	Motif size searched  3
# 	Total number of 3-node subgraphs : 42532
# 	Number of random networks generated : 100
# 	Random networks generation method: Switches
# 	Num of Switches range: 100.0-200.0, Success switches Ratio:0.680+-0.00
#
# The following motifs were found:
#
# Criteria taken : Nreal Zscore > 2.00
#                  Pval ignored (due to small number of random networks)
#                  Mfactor > 1.10
#                  Uniqueness >= 4
#
#
#
# 	Full list includes 3 motifs
#
# MOTIF	NREAL	NRAND		NREAL	NREAL	UNIQ	CREAL
# ID		STATS		ZSCORE	PVAL	VAL	[MILI]
#
# 38	1100	624.0+-40.1	11.86	0.000	26	25.86
#
# 0 1 1
# 0 0 1
# 0 0 0
#
# 46	88	12.9+-6.0	12.63	0.000	6	2.07
#
# 0 1 1
# 1 0 1
# 0 0 0
#
# 108	60	10.2+-3.5	14.13	0.000	6	1.41
#
# 0 0 1
# 1 0 1
# 1 0 0
#
#
#
#  (Application total runtime was:   34.0 seconds.)
#
#  (Real network processing runtime was:    0.0 seconds.)
#
#  (Single Random network processing runtime was:    0.3 seconds.)
#
# Output File motifs_20somite_Notochord_OUT.txt was generated
# Input Network file is filtered_GRN_20somite_PSM_mfinder_format.txt
# mfinder Version 1.20
#
# Loading Network
# 	Reading Network file in <Source,Target,Weight> Format
# Searching motifs size 3
# Processing Real network...
#
#  (Real network processing runtime was:    0.0 seconds.)
# Processing Random networks
# ..........
#  Estimated run time left :     36 seconds.
#
# ..........
#  Estimated run time left :     32 seconds.
#
# ..........
#  Estimated run time left :     28 seconds.
#
# ..........
#  Estimated run time left :     24 seconds.
#
# ..........
#  Estimated run time left :     20 seconds.
#
# ..........
#  Estimated run time left :     16 seconds.
#
# ..........
#  Estimated run time left :     12 seconds.
#
# ..........
#  Estimated run time left :      8 seconds.
#
# ..........
#  Estimated run time left :      4 seconds.
#
# ..........
#  Estimated run time left :      0 seconds.
#
#
# Calculating Results...
#
# MOTIF FINDER RESULTS:
#
# 	Network name: filtered_GRN_20somite_PSM_mfinder_format.txt
# 	Network type: Directed
# 	Num of Nodes: 296 Num 20somite_PSM network motif computing completed
# Somites
# of Edges: 2000
# 	Num of Nodes with edges: 296
# 	Maximal out degree (out-hub) : 114
# 	Maximal in degree (in-hub) : 40
# 	Roots num: 58 Leaves num: 193
# 	Single Edges num: 1923 Mutual Edges num: 38
#
# 	Motif size searched  3
# 	Total number of 3-node subgraphs : 65869
# 	Number of random networks generated : 100
# 	Random networks generation method: Switches
# 	Num of Switches range: 100.0-200.0, Success switches Ratio:0.358+-0.00
#
# The following motifs were found:
#
# Criteria taken : Nreal Zscore > 2.00
#                  Pval ignored (due to small number of random networks)
#                  Mfactor > 1.10
#                  Uniqueness >= 4
#
#
#
# 	Full list includes 1 motifs
#
# MOTIF	NREAL	NRAND		NREAL	NREAL	UNIQ	CREAL
# ID		STATS		ZSCORE	PVAL	VAL	[MILI]
#
# 46	727	574.7+-22.5	6.77	0.000	10	11.04
#
# 0 1 1
# 1 0 1
# 0 0 0
#
#
#
#  (Application total runtime was:   40.0 seconds.)
#
#  (Real network processing runtime was:    0.0 seconds.)
#
#  (Single Random network processing runtime was:    0.4 seconds.)
#
# Output File motifs_20somite_PSM_OUT.txt was generated
# Input Network file is filtered_GRN_20somite_Somites_mfinder_format.txt
# mfinder Version 1.20
#
# Loading Network
# 	Reading Network file in <Source,Target,Weight> Format
# Searching motifs size 3
# Processing Real network...
#
#  (Real network processing runtime was:    0.0 seconds.)
# Processing Random networks
# ..........
#  Estimated run time left :     36 seconds.
#
# ..........
#  Estimated run time left :     28 seconds.
#
# ..........
#  Estimated run time left :     26 seconds.
#
# ..........
#  Estimated run time left :     22 seconds.
#
# ..........
#  Estimated run time left :     18 seconds.
#
# ..........
#  Estimated run time left :     15 seconds.
#
# ..........
#  Estimated run time left :     11 seconds.
#
# ..........
#  Estimated run time left :      7 seconds.
#
# ..........
#  Estimated run time left :      4 seconds.
#
# ..........
#  Estimated run time left :      0 seconds.
#
#
# Calculating Results...
#
# MOTIF FINDER RESULTS:
#
# 	Network name: filtered_GRN_20somite_Somites_mfinder_format.txt
# 	Network type: Directed
# 	Num of Nodes: 20somite_Somites network motif computing completed
# unassigned
# 465 Num of Edges: 2000
# 	Num of Nodes with edges: 465
# 	Maximal out degree (out-hub) : 111
# 	Maximal in degree (in-hub) : 41
# 	Roots num: 127 Leaves num: 281
# 	Single Edges num: 1936 Mutual Edges num: 31
#
# 	Motif size searched  3
# 	Total number of 3-node subgraphs : 43805
# 	Number of random networks generated : 100
# 	Random networks generation method: Switches
# 	Num of Switches range: 100.0-200.0, Success switches Ratio:0.680+-0.00
#
# The following motifs were found:
#
# Criteria taken : Nreal Zscore > 2.00
#                  Pval ignored (due to small number of random networks)
#                  Mfactor > 1.10
#                  Uniqueness >= 4
#
#
#
# 	Full list includes 3 motifs
#
# MOTIF	NREAL	NRAND		NREAL	NREAL	UNIQ	CREAL
# ID		STATS		ZSCORE	PVAL	VAL	[MILI]
#
# 38	1254	822.9+-47.3	9.12	0.000	26	28.63
#
# 0 1 1
# 0 0 1
# 0 0 0
#
# 46	285	175.1+-16.8	6.55	0.000	9	6.51
#
# 0 1 1
# 1 0 1
# 0 0 0
#
# 108	39	15.7+-3.7	6.37	0.000	6	0.89
#
# 0 0 1
# 1 0 1
# 1 0 0
#
#
#
#  (Application total runtime was:   37.0 seconds.)
#
#  (Real network processing runtime was:    0.0 seconds.)
#
#  (Single Random network processing runtime was:    0.4 seconds.)
#
# Output File motifs_20somite_Somites_OUT.txt was generated

# %%
# move to the directory where the output files will be saved
filepath = "/hpc/projects/data.science/yangjoon.kim/zebrahub_multiome/data/processed_data/baseGRN_CisBP_RNA_zebrahub/09_network_motifs/"
os.chdir(filepath)

# %%
# import the Links object
GRN_links_TDR118 = co.load_hdf5("/hpc/projects/data.science/yangjoon.kim/zebrahub_multiome/data/processed_data/TDR118_cicero_output/08_TDR118_celltype_GRNs.celloracle.links")
GRN_links_TDR118

# grab only the filtered object (2000 edges)
GRN_all = GRN_links_TDR118.filtered_links

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 stage
#
# NameError: name 'stage' is not defined

# %%
# Run mFinder for each timepoint, for each celltype, then save the result to the "filepath"

for timepoints in stages:

    for celltype in GRN_all.keys():

        print(celltype)

        # Step 1. subset the GRN for each celltype
        GRN_celltype = GRN_all[celltype]

        # Step 2. reformat the GRN (unique integers for gene_names)    
        list_genes_TFs = list(set(GRN_celltype.source).union(set(GRN_celltype.target)))
        # Create a dictionary mapping integers to gene names
        gene_dict = {index: gene_name for index, gene_name in enumerate(list_genes_TFs)}
        gene_dict

        # Now, we will reformat the GRN as described above
        # 1) grab the GRN, then extract the "source", "target", and create a dataframe
        # 2) add the "edge weight" as "1" for the third column
        df_mfinder = pd.DataFrame(columns =["source", "target", "edge_weight"])
        df_mfinder

        df_mfinder["source"] = GRN_celltype["source"]
        df_mfinder["target"] = GRN_celltype["target"]
        df_mfinder["edge_weight"] = 1

        df_mfinder

        # 3) convert the "source", "target" gene_names to "integers" using the gene_dict
        df_mfinder["source"] = df_mfinder["source"].map({v: k for k, v in gene_dict.items()})
        df_mfinder["target"] = df_mfinder["target"].map({v: k for k, v in gene_dict.items()})
        df_mfinder
        # save the reformatted GRN into a txt file
        df_mfinder.to_csv(filepath + "filtered_GRN_"+celltype+"_mfinder_format.txt",
                          sep="\t", header=False, index=False)

        # Step 3. run mFinder
        # default setting (network_size=3, num_random_)
        # input filename
        input_file = "filtered_GRN_"+celltype+"_mfinder_format.txt"
        # output filename
        output_file = "motifs_" + celltype

        # define the mFinder command
        cmd = "mfinder "+input_file + " -f "+output_file
        cmd
        # run mFinder
        os.system(cmd)
        print(celltype + " network motif computing completed")
# Out:
# Adaxial_Cells
# Input Network file is filtered_GRN_Adaxial_Cells_mfinder_format.txt
# mfinder Version 1.20
#
# Loading Network
# 	Reading Network file in <Source,Target,Weight> Format
# Searching motifs size 3
# Processing Real network...
#
#  (Real network processing runtime was:    1.0 seconds.)
# Processing Random networks
# ..........
#  Estimated run time left :     18 seconds.
#
# ..........
#  Estimated run time left :     20 seconds.
#
# ..........
#  Estimated run time left :     19 seconds.
#
# ..........
#  Estimated run time left :     16 seconds.
#
# ..........
#  Estimated run time left :     14 seconds.
#
# ..........
#  Estimated run time left :     11 seconds.
#
# ..........
#  Estimated run time left :      9 seconds.
#
# ..........
#  Estimated run time left :      6 seconds.
#
# ..........
#  Estimated run time left :      3 seconds.
#
# ..........
#  Estimated run time left :      0 seconds.
#
#
# Calculating Results...
#
# MOTIF FINDER RESULTS:
#
# 	Network name: filtered_GRN_Adaxial_Cells_mfinder_format.txt
# 	Network type: Directed
# 	Num of Nodes: 455 NuAdaxial_Cells network motif computing completed
# Differentiating_Neurons
# m of Edges: 2000
# 	Num of Nodes with edges: 455
# 	Maximal out degree (out-hub) : 56
# 	Maximal in degree (in-hub) : 47
# 	Roots num: 212 Leaves num: 211
# 	Single Edges num: 1973 Mutual Edges num: 11
#
# 	Motif size searched  3
# 	Total number of 3-node subgraphs : 36825
# 	Number of random networks generated : 100
# 	Random networks generation method: Switches
# 	Num of Switches range: 100.0-200.0, Success switches Ratio:0.720+-0.00
#
# The following motifs were found:
#
# Criteria taken : Nreal Zscore > 2.00
#                  Pval ignored (due to small number of random networks)
#                  Mfactor > 1.10
#                  Uniqueness >= 4
#
#
#
# 	Full list includes 3 motifs
#
# MOTIF	NREAL	NRAND		NREAL	NREAL	UNIQ	CREAL
# ID		STATS		ZSCORE	PVAL	VAL	[MILI]
#
# 38	760	601.8+-38.9	4.07	0.000	18	20.64
#
# 0 1 1
# 0 0 1
# 0 0 0
#
# 46	61	36.7+-5.8	4.22	0.000	5	1.66
#
# 0 1 1
# 1 0 1
# 0 0 0
#
# 108	26	14.2+-4.4	2.66	0.020	5	0.71
#
# 0 0 1
# 1 0 1
# 1 0 0
#
#
#
#  (Application total runtime was:   30.0 seconds.)
#
#  (Real network processing runtime was:    1.0 seconds.)
#
#  (Single Random network processing runtime was:    0.3 seconds.)
#
# Output File motifs_Adaxial_Cells_OUT.txt was generated
# Input Network file is filtered_GRN_Differentiating_Neurons_mfinder_format.txt
# mfinder Version 1.20
#
# Loading Network
# 	Reading Network file in <Source,Target,Weight> Format
# Searching motifs size 3
# Processing Real network...
#
#  (Real network processing runtime was:    0.0 seconds.)
# Processing Random networks
# ..........
#  Estimated run time left :     27 seconds.
#
# ..........
#  Estimated run time left :     24 seconds.
#
# ..........
#  Estimated run time left :     19 seconds.
#
# ..........
#  Estimated run time left :     16 seconds.
#
# ..........
#  Estimated run time left :     14 seconds.
#
# ..........
#  Estimated run time left :     11 seconds.
#
# ..........
#  Estimated run time left :      9 seconds.
#
# ..........
#  Estimated run time left :      6 seconds.
#
# ..........
#  Estimated run time left :      3 seconds.
#
# ..........
#  Estimated run time left :      0 seconds.
#
#
# Calculating Results...
#
# MOTIF FINDER RESULTS:
#
# 	Network name: filtered_GRN_Differentiating_Neurons_mfinder_format.txt
# 	Network type: Directed
# 	Differentiating_Neurons network motif computing completed
# Endoderm
# Num of Nodes: 443 Num of Edges: 2000
# 	Num of Nodes with edges: 443
# 	Maximal out degree (out-hub) : 41
# 	Maximal in degree (in-hub) : 51
# 	Roots num: 227 Leaves num: 179
# 	Single Edges num: 1973 Mutual Edges num: 11
#
# 	Motif size searched  3
# 	Total number of 3-node subgraphs : 38336
# 	Number of random networks generated : 100
# 	Random networks generation method: Switches
# 	Num of Switches range: 100.0-200.0, Success switches Ratio:0.692+-0.00
#
# The following motifs were found:
#
# Criteria taken : Nreal Zscore > 2.00
#                  Pval ignored (due to small number of random networks)
#                  Mfactor > 1.10
#                  Uniqueness >= 4
#
#
#
# 	Full list includes 0 motifs
#
# MOTIF	NREAL	NRAND		NREAL	NREAL	UNIQ	CREAL
# ID		STATS		ZSCORE	PVAL	VAL	[MILI]
#
#
#
#  (Application total runtime was:   30.0 seconds.)
#
#  (Real network processing runtime was:    0.0 seconds.)
#
#  (Single Random network processing runtime was:    0.3 seconds.)
#
# Output File motifs_Differentiating_Neurons_OUT.txt was generated
# Input Network file is filtered_GRN_Endoderm_mfinder_format.txt
# mfinder Version 1.20
#
# Loading Network
# 	Reading Network file in <Source,Target,Weight> Format
# Searching motifs size 3
# Processing Real network...
#
#  (Real network processing runtime was:    0.0 seconds.)
# Processing Random networks
# ..........
#  Estimated run time left :     27 seconds.
#
# ..........
#  Estimated run time left :     24 seconds.
#
# ..........
#  Estimated run time left :     21 seconds.
#
# ..........
#  Estimated run time left :     18 seconds.
#
# ..........
#  Estimated run time left :     14 seconds.
#
# ..........
#  Estimated run time left :     12 seconds.
#
# ..........
#  Estimated run time left :      9 seconds.
#
# ..........
#  Estimated run time left :      6 seconds.
#
# ..........
#  Estimated run time left :      3 seconds.
#
# ..........
#  Estimated run time left :      0 seconds.
#
#
# Calculating Results...
#
# MOTIF FINDER RESULTS:
#
# 	Network name: filtered_GRN_Endoderm_mfinder_format.txt
# 	Network type: Directed
# 	Num of Nodes: 455 Num of EdgesEndoderm network motif computing completed
# Epidermal
# : 2000
# 	Num of Nodes with edges: 455
# 	Maximal out degree (out-hub) : 47
# 	Maximal in degree (in-hub) : 46
# 	Roots num: 220 Leaves num: 195
# 	Single Edges num: 1981 Mutual Edges num: 8
#
# 	Motif size searched  3
# 	Total number of 3-node subgraphs : 39285
# 	Number of random networks generated : 100
# 	Random networks generation method: Switches
# 	Num of Switches range: 100.0-200.0, Success switches Ratio:0.680+-0.00
#
# The following motifs were found:
#
# Criteria taken : Nreal Zscore > 2.00
#                  Pval ignored (due to small number of random networks)
#                  Mfactor > 1.10
#                  Uniqueness >= 4
#
#
#
# 	Full list includes 0 motifs
#
# MOTIF	NREAL	NRAND		NREAL	NREAL	UNIQ	CREAL
# ID		STATS		ZSCORE	PVAL	VAL	[MILI]
#
#
#
#  (Application total runtime was:   29.0 seconds.)
#
#  (Real network processing runtime was:    0.0 seconds.)
#
#  (Single Random network processing runtime was:    0.3 seconds.)
#
# Output File motifs_Endoderm_OUT.txt was generated
# Input Network file is filtered_GRN_Epidermal_mfinder_format.txt
# mfinder Version 1.20
#
# Loading Network
# 	Reading Network file in <Source,Target,Weight> Format
# Searching motifs size 3
# Processing Real network...
#
#  (Real network processing runtime was:    0.0 seconds.)
# Processing Random networks
# ..........
#  Estimated run time left :     36 seconds.
#
# ..........
#  Estimated run time left :     28 seconds.
#
# ..........
#  Estimated run time left :     21 seconds.
#
# ..........
#  Estimated run time left :     20 seconds.
#
# ..........
#  Estimated run time left :     15 seconds.
#
# ..........
#  Estimated run time left :     12 seconds.
#
# ..........
#  Estimated run time left :      9 seconds.
#
# ..........
#  Estimated run time left :      6 seconds.
#
# ..........
#  Estimated run time left :      3 seconds.
#
# ..........
#  Estimated run time left :      0 seconds.
#
#
# Calculating Results...
#
# MOTIF FINDER RESULTS:
#
# 	Network name: filtered_GRN_Epidermal_mfinder_format.txt
# 	Network type: Directed
# 	Num of Nodes: 475 Num of EdgEpidermal network motif computing completed
# Lateral_Mesoderm
# es: 2000
# 	Num of Nodes with edges: 475
# 	Maximal out degree (out-hub) : 63
# 	Maximal in degree (in-hub) : 50
# 	Roots num: 198 Leaves num: 237
# 	Single Edges num: 1975 Mutual Edges num: 11
#
# 	Motif size searched  3
# 	Total number of 3-node subgraphs : 40218
# 	Number of random networks generated : 100
# 	Random networks generation method: Switches
# 	Num of Switches range: 100.0-200.0, Success switches Ratio:0.661+-0.00
#
# The following motifs were found:
#
# Criteria taken : Nreal Zscore > 2.00
#                  Pval ignored (due to small number of random networks)
#                  Mfactor > 1.10
#                  Uniqueness >= 4
#
#
#
# 	Full list includes 0 motifs
#
# MOTIF	NREAL	NRAND		NREAL	NREAL	UNIQ	CREAL
# ID		STATS		ZSCORE	PVAL	VAL	[MILI]
#
#
#
#  (Application total runtime was:   31.0 seconds.)
#
#  (Real network processing runtime was:    0.0 seconds.)
#
#  (Single Random network processing runtime was:    0.3 seconds.)
#
# Output File motifs_Epidermal_OUT.txt was generated
# Input Network file is filtered_GRN_Lateral_Mesoderm_mfinder_format.txt
# mfinder Version 1.20
#
# Loading Network
# 	Reading Network file in <Source,Target,Weight> Format
# Searching motifs size 3
# Processing Real network...
#
#  (Real network processing runtime was:    0.0 seconds.)
# Processing Random networks
# ..........
#  Estimated run time left :     27 seconds.
#
# ..........
#  Estimated run time left :     24 seconds.
#
# ..........
#  Estimated run time left :     21 seconds.
#
# ..........
#  Estimated run time left :     18 seconds.
#
# ..........
#  Estimated run time left :     15 seconds.
#
# ..........
#  Estimated run time left :     12 seconds.
#
# ..........
#  Estimated run time left :      9 seconds.
#
# ..........
#  Estimated run time left :      6 seconds.
#
# ..........
#  Estimated run time left :      3 seconds.
#
# ..........
#  Estimated run time left :      0 seconds.
#
#
# Calculating Results...
#
# MOTIF FINDER RESULTS:
#
# 	Network name: filtered_GRN_Lateral_Mesoderm_mfinder_format.txt
# 	Network type: Directed
# 	Num of Nodes: Lateral_Mesoderm network motif computing completed
# Muscle
# 492 Num of Edges: 2000
# 	Num of Nodes with edges: 492
# 	Maximal out degree (out-hub) : 53
# 	Maximal in degree (in-hub) : 44
# 	Roots num: 175 Leaves num: 266
# 	Single Edges num: 1970 Mutual Edges num: 13
#
# 	Motif size searched  3
# 	Total number of 3-node subgraphs : 39959
# 	Number of random networks generated : 100
# 	Random networks generation method: Switches
# 	Num of Switches range: 100.0-200.0, Success switches Ratio:0.669+-0.00
#
# The following motifs were found:
#
# Criteria taken : Nreal Zscore > 2.00
#                  Pval ignored (due to small number of random networks)
#                  Mfactor > 1.10
#                  Uniqueness >= 4
#
#
#
# 	Full list includes 0 motifs
#
# MOTIF	NREAL	NRAND		NREAL	NREAL	UNIQ	CREAL
# ID		STATS		ZSCORE	PVAL	VAL	[MILI]
#
#
#
#  (Application total runtime was:   31.0 seconds.)
#
#  (Real network processing runtime was:    0.0 seconds.)
#
#  (Single Random network processing runtime was:    0.3 seconds.)
#
# Output File motifs_Lateral_Mesoderm_OUT.txt was generated
# Input Network file is filtered_GRN_Muscle_mfinder_format.txt
# mfinder Version 1.20
#
# Loading Network
# 	Reading Network file in <Source,Target,Weight> Format
# Searching motifs size 3
# Processing Real network...
#
#  (Real network processing runtime was:    0.0 seconds.)
# Processing Random networks
# ..........
#  Estimated run time left :     27 seconds.
#
# ..........
#  Estimated run time left :     20 seconds.
#
# ..........
#  Estimated run time left :     19 seconds.
#
# ..........
#  Estimated run time left :     16 seconds.
#
# ..........
#  Estimated run time left :     14 seconds.
#
# ..........
#  Estimated run time left :     11 seconds.
#
# ..........
#  Estimated run time left :      9 seconds.
#
# ..........
#  Estimated run time left :      6 seconds.
#
# ..........
#  Estimated run time left :      3 seconds.
#
# ..........
#  Estimated run time left :      0 seconds.
#
#
# Calculating Results...
#
# MOTIF FINDER RESULTS:
#
# 	Network name: filtered_GRN_Muscle_mfinder_format.txt
# 	Network type: Directed
# 	Num of Nodes: 491 Num of Edges: 20Muscle network motif computing completed
# NMPs
# 00
# 	Num of Nodes with edges: 491
# 	Maximal out degree (out-hub) : 53
# 	Maximal in degree (in-hub) : 42
# 	Roots num: 239 Leaves num: 217
# 	Single Edges num: 1978 Mutual Edges num: 10
#
# 	Motif size searched  3
# 	Total number of 3-node subgraphs : 36321
# 	Number of random networks generated : 100
# 	Random networks generation method: Switches
# 	Num of Switches range: 100.0-200.0, Success switches Ratio:0.729+-0.00
#
# The following motifs were found:
#
# Criteria taken : Nreal Zscore > 2.00
#                  Pval ignored (due to small number of random networks)
#                  Mfactor > 1.10
#                  Uniqueness >= 4
#
#
#
# 	Full list includes 0 motifs
#
# MOTIF	NREAL	NRAND		NREAL	NREAL	UNIQ	CREAL
# ID		STATS		ZSCORE	PVAL	VAL	[MILI]
#
#
#
#  (Application total runtime was:   29.0 seconds.)
#
#  (Real network processing runtime was:    0.0 seconds.)
#
#  (Single Random network processing runtime was:    0.3 seconds.)
#
# Output File motifs_Muscle_OUT.txt was generated
# Input Network file is filtered_GRN_NMPs_mfinder_format.txt
# mfinder Version 1.20
#
# Loading Network
# 	Reading Network file in <Source,Target,Weight> Format
# Searching motifs size 3
# Processing Real network...
#
#  (Real network processing runtime was:    0.0 seconds.)
# Processing Random networks
# ..........
#  Estimated run time left :     27 seconds.
#
# ..........
#  Estimated run time left :     24 seconds.
#
# ..........
#  Estimated run time left :     21 seconds.
#
# ..........
#  Estimated run time left :     20 seconds.
#
# ..........
#  Estimated run time left :     16 seconds.
#
# ..........
#  Estimated run time left :     13 seconds.
#
# ..........
#  Estimated run time left :      9 seconds.
#
# ..........
#  Estimated run time left :      6 seconds.
#
# ..........
#  Estimated run time left :      3 seconds.
#
# ..........
#  Estimated run time left :      0 seconds.
#
#
# Calculating Results...
#
# MOTIF FINDER RESULTS:
#
# 	Network name: filtered_GRN_NMPs_mfinder_format.txt
# 	Network type: Directed
# 	Num of Nodes: 389 Num of Edges: 2000
# 	NMPs network motif computing completed
# Neural_Anterior
# Num of Nodes with edges: 389
# 	Maximal out degree (out-hub) : 39
# 	Maximal in degree (in-hub) : 60
# 	Roots num: 236 Leaves num: 127
# 	Single Edges num: 1959 Mutual Edges num: 15
#
# 	Motif size searched  3
# 	Total number of 3-node subgraphs : 43793
# 	Number of random networks generated : 100
# 	Random networks generation method: Switches
# 	Num of Switches range: 100.0-200.0, Success switches Ratio:0.625+-0.00
#
# The following motifs were found:
#
# Criteria taken : Nreal Zscore > 2.00
#                  Pval ignored (due to small number of random networks)
#                  Mfactor > 1.10
#                  Uniqueness >= 4
#
#
#
# 	Full list includes 2 motifs
#
# MOTIF	NREAL	NRAND		NREAL	NREAL	UNIQ	CREAL
# ID		STATS		ZSCORE	PVAL	VAL	[MILI]
#
# 38	578	483.3+-29.7	3.18	0.000	13	13.20
#
# 0 1 1
# 0 0 1
# 0 0 0
#
# 108	23	6.8+-2.6	6.34	0.000	4	0.53
#
# 0 0 1
# 1 0 1
# 1 0 0
#
#
#
#  (Application total runtime was:   31.0 seconds.)
#
#  (Real network processing runtime was:    0.0 seconds.)
#
#  (Single Random network processing runtime was:    0.3 seconds.)
#
# Output File motifs_NMPs_OUT.txt was generated
# Input Network file is filtered_GRN_Neural_Anterior_mfinder_format.txt
# mfinder Version 1.20
#
# Loading Network
# 	Reading Network file in <Source,Target,Weight> Format
# Searching motifs size 3
# Processing Real network...
#
#  (Real network processing runtime was:    0.0 seconds.)
# Processing Random networks
# ..........
#  Estimated run time left :     27 seconds.
#
# ..........
#  Estimated run time left :     24 seconds.
#
# ..........
#  Estimated run time left :     21 seconds.
#
# ..........
#  Estimated run time left :     18 seconds.
#
# ..........
#  Estimated run time left :     15 seconds.
#
# ..........
#  Estimated run time left :     13 seconds.
#
# ..........
#  Estimated run time left :      9 seconds.
#
# ..........
#  Estimated run time left :      6 seconds.
#
# ..........
#  Estimated run time left :      3 seconds.
#
# ..........
#  Estimated run time left :      0 seconds.
#
#
# Calculating Results...
#
# MOTIF FINDER RESULTS:
#
# 	Network name: filtered_GRN_Neural_Anterior_mfinder_format.txt
# 	Network type: Directed
# 	Num of Nodes: 42Neural_Anterior network motif computing completed
# Neural_Crest
# 3 Num of Edges: 2000
# 	Num of Nodes with edges: 423
# 	Maximal out degree (out-hub) : 46
# 	Maximal in degree (in-hub) : 49
# 	Roots num: 183 Leaves num: 197
# 	Single Edges num: 1980 Mutual Edges num: 8
#
# 	Motif size searched  3
# 	Total number of 3-node subgraphs : 43052
# 	Number of random networks generated : 100
# 	Random networks generation method: Switches
# 	Num of Switches range: 100.0-200.0, Success switches Ratio:0.626+-0.00
#
# The following motifs were found:
#
# Criteria taken : Nreal Zscore > 2.00
#                  Pval ignored (due to small number of random networks)
#                  Mfactor > 1.10
#                  Uniqueness >= 4
#
#
#
# 	Full list includes 0 motifs
#
# MOTIF	NREAL	NRAND		NREAL	NREAL	UNIQ	CREAL
# ID		STATS		ZSCORE	PVAL	VAL	[MILI]
#
#
#
#  (Application total runtime was:   31.0 seconds.)
#
#  (Real network processing runtime was:    0.0 seconds.)
#
#  (Single Random network processing runtime was:    0.3 seconds.)
#
# Output File motifs_Neural_Anterior_OUT.txt was generated
# Input Network file is filtered_GRN_Neural_Crest_mfinder_format.txt
# mfinder Version 1.20
#
# Loading Network
# 	Reading Network file in <Source,Target,Weight> Format
# Searching motifs size 3
# Processing Real network...
#
#  (Real network processing runtime was:    0.0 seconds.)
# Processing Random networks
# ..........
#  Estimated run time left :     27 seconds.
#
# ..........
#  Estimated run time left :     24 seconds.
#
# ..........
#  Estimated run time left :     21 seconds.
#
# ..........
#  Estimated run time left :     18 seconds.
#
# ..........
#  Estimated run time left :     15 seconds.
#
# ..........
#  Estimated run time left :     12 seconds.
#
# ..........
#  Estimated run time left :      9 seconds.
#
# ..........
#  Estimated run time left :      6 seconds.
#
# ..........
#  Estimated run time left :      3 seconds.
#
# ..........
#  Estimated run time left :      0 seconds.
#
#
# Calculating Results...
#
# MOTIF FINDER RESULTS:
#
# 	Network name: filtered_GRN_Neural_Crest_mfinder_format.txt
# 	Network type: Directed
# 	Num of Nodes: 418 Num Neural_Crest network motif computing completed
# Neural_Posterior
# of Edges: 2000
# 	Num of Nodes with edges: 418
# 	Maximal out degree (out-hub) : 49
# 	Maximal in degree (in-hub) : 52
# 	Roots num: 194 Leaves num: 183
# 	Single Edges num: 1972 Mutual Edges num: 12
#
# 	Motif size searched  3
# 	Total number of 3-node subgraphs : 42897
# 	Number of random networks generated : 100
# 	Random networks generation method: Switches
# 	Num of Switches range: 100.0-200.0, Success switches Ratio:0.632+-0.00
#
# The following motifs were found:
#
# Criteria taken : Nreal Zscore > 2.00
#                  Pval ignored (due to small number of random networks)
#                  Mfactor > 1.10
#                  Uniqueness >= 4
#
#
#
# 	Full list includes 0 motifs
#
# MOTIF	NREAL	NRAND		NREAL	NREAL	UNIQ	CREAL
# ID		STATS		ZSCORE	PVAL	VAL	[MILI]
#
#
#
#  (Application total runtime was:   31.0 seconds.)
#
#  (Real network processing runtime was:    0.0 seconds.)
#
#  (Single Random network processing runtime was:    0.3 seconds.)
#
# Output File motifs_Neural_Crest_OUT.txt was generated
# Input Network file is filtered_GRN_Neural_Posterior_mfinder_format.txt
# mfinder Version 1.20
#
# Loading Network
# 	Reading Network file in <Source,Target,Weight> Format
# Searching motifs size 3
# Processing Real network...
#
#  (Real network processing runtime was:    0.0 seconds.)
# Processing Random networks
# ..........
#  Estimated run time left :     27 seconds.
#
# ..........
#  Estimated run time left :     24 seconds.
#
# ..........
#  Estimated run time left :     21 seconds.
#
# ..........
#  Estimated run time left :     18 seconds.
#
# ..........
#  Estimated run time left :     15 seconds.
#
# ..........
#  Estimated run time left :     13 seconds.
#
# ..........
#  Estimated run time left :      9 seconds.
#
# ..........
#  Estimated run time left :      6 seconds.
#
# ..........
#  Estimated run time left :      3 seconds.
#
# ..........
#  Estimated run time left :      0 seconds.
#
#
# Calculating Results...
#
# MOTIF FINDER RESULTS:
#
# 	Network name: filtered_GRN_Neural_Posterior_mfinder_format.txt
# 	Network type: Directed
# 	Num of Nodes: Neural_Posterior network motif computing completed
# Notochord
# 435 Num of Edges: 2000
# 	Num of Nodes with edges: 435
# 	Maximal out degree (out-hub) : 51
# 	Maximal in degree (in-hub) : 44
# 	Roots num: 189 Leaves num: 200
# 	Single Edges num: 1958 Mutual Edges num: 18
#
# 	Motif size searched  3
# 	Total number of 3-node subgraphs : 40904
# 	Number of random networks generated : 100
# 	Random networks generation method: Switches
# 	Num of Switches range: 100.0-200.0, Success switches Ratio:0.647+-0.00
#
# The following motifs were found:
#
# Criteria taken : Nreal Zscore > 2.00
#                  Pval ignored (due to small number of random networks)
#                  Mfactor > 1.10
#                  Uniqueness >= 4
#
#
#
# 	Full list includes 1 motifs
#
# MOTIF	NREAL	NRAND		NREAL	NREAL	UNIQ	CREAL
# ID		STATS		ZSCORE	PVAL	VAL	[MILI]
#
# 108	12	5.5+-2.2	2.92	0.010	4	0.29
#
# 0 0 1
# 1 0 1
# 1 0 0
#
#
#
#  (Application total runtime was:   31.0 seconds.)
#
#  (Real network processing runtime was:    0.0 seconds.)
#
#  (Single Random network processing runtime was:    0.3 seconds.)
#
# Output File motifs_Neural_Posterior_OUT.txt was generated
# Input Network file is filtered_GRN_Notochord_mfinder_format.txt
# mfinder Version 1.20
#
# Loading Network
# 	Reading Network file in <Source,Target,Weight> Format
# Searching motifs size 3
# Processing Real network...
#
#  (Real network processing runtime was:    0.0 seconds.)
# Processing Random networks
# ..........
#  Estimated run time left :     27 seconds.
#
# ..........
#  Estimated run time left :     20 seconds.
#
# ..........
#  Estimated run time left :     19 seconds.
#
# ..........
#  Estimated run time left :     16 seconds.
#
# ..........
#  Estimated run time left :     14 seconds.
#
# ..........
#  Estimated run time left :     11 seconds.
#
# ..........
#  Estimated run time left :      9 seconds.
#
# ..........
#  Estimated run time left :      6 seconds.
#
# ..........
#  Estimated run time left :      3 seconds.
#
# ..........
#  Estimated run time left :      0 seconds.
#
#
# Calculating Results...
#
# MOTIF FINDER RESULTS:
#
# 	Network name: filtered_GRN_Notochord_mfinder_format.txt
# 	Network type: Directed
# 	Num of Nodes: 447 Num of EdgNotochord network motif computing completed
# PSM
# es: 2000
# 	Num of Nodes with edges: 447
# 	Maximal out degree (out-hub) : 33
# 	Maximal in degree (in-hub) : 47
# 	Roots num: 244 Leaves num: 170
# 	Single Edges num: 1980 Mutual Edges num: 7
#
# 	Motif size searched  3
# 	Total number of 3-node subgraphs : 36582
# 	Number of random networks generated : 100
# 	Random networks generation method: Switches
# 	Num of Switches range: 100.0-200.0, Success switches Ratio:0.716+-0.00
#
# The following motifs were found:
#
# Criteria taken : Nreal Zscore > 2.00
#                  Pval ignored (due to small number of random networks)
#                  Mfactor > 1.10
#                  Uniqueness >= 4
#
#
#
# 	Full list includes 2 motifs
#
# MOTIF	NREAL	NRAND		NREAL	NREAL	UNIQ	CREAL
# ID		STATS		ZSCORE	PVAL	VAL	[MILI]
#
# 38	517	294.1+-23.4	9.52	0.000	19	14.13
#
# 0 1 1
# 0 0 1
# 0 0 0
#
# 46	19	11.0+-2.9	2.77	0.010	5	0.52
#
# 0 1 1
# 1 0 1
# 0 0 0
#
#
#
#  (Application total runtime was:   28.0 seconds.)
#
#  (Real network processing runtime was:    0.0 seconds.)
#
#  (Single Random network processing runtime was:    0.3 seconds.)
#
# Output File motifs_Notochord_OUT.txt was generated
# Input Network file is filtered_GRN_PSM_mfinder_format.txt
# mfinder Version 1.20
#
# Loading Network
# 	Reading Network file in <Source,Target,Weight> Format
# Searching motifs size 3
# Processing Real network...
#
#  (Real network processing runtime was:    1.0 seconds.)
# Processing Random networks
# ..........
#  Estimated run time left :     18 seconds.
#
# ..........
#  Estimated run time left :     20 seconds.
#
# ..........
#  Estimated run time left :     19 seconds.
#
# ..........
#  Estimated run time left :     16 seconds.
#
# ..........
#  Estimated run time left :     14 seconds.
#
# ..........
#  Estimated run time left :     12 seconds.
#
# ..........
#  Estimated run time left :      9 seconds.
#
# ..........
#  Estimated run time left :      6 seconds.
#
# ..........
#  Estimated run time left :      3 seconds.
#
# ..........
#  Estimated run time left :      0 seconds.
#
#
# Calculating Results...
#
# MOTIF FINDER RESULTS:
#
# 	Network name: filtered_GRN_PSM_mfinder_format.txt
# 	Network type: Directed
# 	Num of Nodes: 448 Num of Edges: 2000
# 	NuPSM network motif computing completed
# Somites
# m of Nodes with edges: 448
# 	Maximal out degree (out-hub) : 61
# 	Maximal in degree (in-hub) : 65
# 	Roots num: 229 Leaves num: 185
# 	Single Edges num: 1947 Mutual Edges num: 24
#
# 	Motif size searched  3
# 	Total number of 3-node subgraphs : 41785
# 	Number of random networks generated : 100
# 	Random networks generation method: Switches
# 	Num of Switches range: 100.0-200.0, Success switches Ratio:0.652+-0.00
#
# The following motifs were found:
#
# Criteria taken : Nreal Zscore > 2.00
#                  Pval ignored (due to small number of random networks)
#                  Mfactor > 1.10
#                  Uniqueness >= 4
#
#
#
# 	Full list includes 1 motifs
#
# MOTIF	NREAL	NRAND		NREAL	NREAL	UNIQ	CREAL
# ID		STATS		ZSCORE	PVAL	VAL	[MILI]
#
# 108	18	9.4+-3.2	2.70	0.010	4	0.43
#
# 0 0 1
# 1 0 1
# 1 0 0
#
#
#
#  (Application total runtime was:   32.0 seconds.)
#
#  (Real network processing runtime was:    1.0 seconds.)
#
#  (Single Random network processing runtime was:    0.3 seconds.)
#
# Output File motifs_PSM_OUT.txt was generated
# Input Network file is filtered_GRN_Somites_mfinder_format.txt
# mfinder Version 1.20
#
# Loading Network
# 	Reading Network file in <Source,Target,Weight> Format
# Searching motifs size 3
# Processing Real network...
#
#  (Real network processing runtime was:    0.0 seconds.)
# Processing Random networks
# ..........
#  Estimated run time left :     27 seconds.
#
# ..........
#  Estimated run time left :     24 seconds.
#
# ..........
#  Estimated run time left :     21 seconds.
#
# ..........
#  Estimated run time left :     18 seconds.
#
# ..........
#  Estimated run time left :     15 seconds.
#
# ..........
#  Estimated run time left :     12 seconds.
#
# ..........
#  Estimated run time left :      9 seconds.
#
# ..........
#  Estimated run time left :      6 seconds.
#
# ..........
#  Estimated run time left :      3 seconds.
#
# ..........
#  Estimated run time left :      0 seconds.
#
#
# Calculating Results...
#
# MOTIF FINDER RESULTS:
#
# 	Network name: filtered_GRN_Somites_mfinder_format.txt
# 	Network type: Directed
# 	Num of Nodes: 455 Num of Edges: Somites network motif computing completed
# unassigned
# 2000
# 	Num of Nodes with edges: 455
# 	Maximal out degree (out-hub) : 49
# 	Maximal in degree (in-hub) : 56
# 	Roots num: 227 Leaves num: 191
# 	Single Edges num: 1962 Mutual Edges num: 15
#
# 	Motif size searched  3
# 	Total number of 3-node subgraphs : 41442
# 	Number of random networks generated : 100
# 	Random networks generation method: Switches
# 	Num of Switches range: 100.0-200.0, Success switches Ratio:0.658+-0.00
#
# The following motifs were found:
#
# Criteria taken : Nreal Zscore > 2.00
#                  Pval ignored (due to small number of random networks)
#                  Mfactor > 1.10
#                  Uniqueness >= 4
#
#
#
# 	Full list includes 1 motifs
#
# MOTIF	NREAL	NRAND		NREAL	NREAL	UNIQ	CREAL
# ID		STATS		ZSCORE	PVAL	VAL	[MILI]
#
# 108	20	7.2+-2.9	4.38	0.000	5	0.48
#
# 0 0 1
# 1 0 1
# 1 0 0
#
#
#
#  (Application total runtime was:   31.0 seconds.)
#
#  (Real network processing runtime was:    0.0 seconds.)
#
#  (Single Random network processing runtime was:    0.3 seconds.)
#
# Output File motifs_Somites_OUT.txt was generated
# Input Network file is filtered_GRN_unassigned_mfinder_format.txt
# mfinder Version 1.20
#
# Loading Network
# 	Reading Network file in <Source,Target,Weight> Format
# Searching motifs size 3
# Processing Real network...
#
#  (Real network processing runtime was:    0.0 seconds.)
# Processing Random networks
# ..........
#  Estimated run time left :     27 seconds.
#
# ..........
#  Estimated run time left :     24 seconds.
#
# ..........
#  Estimated run time left :     23 seconds.
#
# ..........
#  Estimated run time left :     20 seconds.
#
# ..........
#  Estimated run time left :     16 seconds.
#
# ..........
#  Estimated run time left :     13 seconds.
#
# ..........
#  Estimated run time left :     10 seconds.
#
# ..........
#  Estimated run time left :      6 seconds.
#
# ..........
#  Estimated run time left :      3 seconds.
#
# ..........
#  Estimated run time left :      0 seconds.
#
#
# Calculating Results...
#
# MOTIF FINDER RESULTS:
#
# 	Network name: filtered_GRN_unassigned_mfinder_format.txt
# 	Network type: Directed
# 	Num of Nodes: 392 Num of Eunassigned network motif computing completed
# dges: 2000
# 	Num of Nodes with edges: 392
# 	Maximal out degree (out-hub) : 29
# 	Maximal in degree (in-hub) : 76
# 	Roots num: 259 Leaves num: 113
# 	Single Edges num: 1973 Mutual Edges num: 5
#
# 	Motif size searched  3
# 	Total number of 3-node subgraphs : 50843
# 	Number of random networks generated : 100
# 	Random networks generation method: Switches
# 	Num of Switches range: 100.0-200.0, Success switches Ratio:0.601+-0.00
#
# The following motifs were found:
#
# Criteria taken : Nreal Zscore > 2.00
#                  Pval ignored (due to small number of random networks)
#                  Mfactor > 1.10
#                  Uniqueness >= 4
#
#
#
# 	Full list includes 0 motifs
#
# MOTIF	NREAL	NRAND		NREAL	NREAL	UNIQ	CREAL
# ID		STATS		ZSCORE	PVAL	VAL	[MILI]
#
#
#
#  (Application total runtime was:   32.0 seconds.)
#
#  (Real network processing runtime was:    0.0 seconds.)
#
#  (Single Random network processing runtime was:    0.3 seconds.)
#
# Output File motifs_unassigned_OUT.txt was generated

# %%
# for celltype in GRN_all.keys():
    
#     print(celltype)
    
#     # Step 3. run mFinder
#     # default setting (network_size=3, num_random_)
#     # input filename
#     input_file = "filtered_GRN_"+celltype+"_mfinder_format.txt"
#     # output filename
#     output_file = "motifs_" + celltype

#     # define the mFinder command
#     cmd = "mfinder "+input_file + " -f "+output_file
#     cmd
#     # run mFinder
#     os.system(cmd)

# %% [markdown]
# NOTES
# - Refer to mFinder documentation (Uri Alon's lab website)
# - link:
#
# 1) Use "screen"
# 2) the motif computation takes less than a minute (with the default settings, network_size=3, for a GRN with 2000 edges, from CellOracle).
# 3) however, if we increase the network_size=4, the runtime increased to 20 minutes, for the same input dataset.
